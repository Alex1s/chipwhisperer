# %% [markdown]
# # Stats - Signature - Only - Attack

# %%
import sys
if '../../../software' not in sys.path:
    sys.path.append('../../../software')
if 'python-dilithium' not in sys.path:
    sys.path.append('python-dilithium')
if 'dilithium_solver' not in sys.path:
    sys.path.append('dilithium_solver')
sys.path
# Out:
# ['/Users/alexis/git/chipwhisperer/jupyter-dilithium',
#  '/usr/local/Cellar/python@3.11/3.11.2_1/Frameworks/Python.framework/Versions/3.11/lib/python311.zip',
#  '/usr/local/Cellar/python@3.11/3.11.2_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11',
#  '/usr/local/Cellar/python@3.11/3.11.2_1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/lib-dynload',
#  '',
#  '/Users/alexis/git/chipwhisperer/jupyter-dilithium/.venv/lib/python3.11/site-packages',
#  '../software',
#  '../python-dilithium',
#  '../dilithium_solver']

# %%
import logging
logging.basicConfig(level=logging.DEBUG)
logging.getLogger('io.github.alex1s.python-dilithium').setLevel(logging.DEBUG)

# %%
import json
import ipywidgets as widgets
from collections import defaultdict
import pickle
import math
import numpy as np
from dilithium import Dilithium
import random
import chipwhisperer.common.results.glitch as glitch
import pandas as pd
from operator import itemgetter
import itertools
from frozendict import frozendict
import logging
import matplotlib.pyplot as plt
import enum
# Out:
# DEBUG:io.github.alex1s.python-dilithium:https://github.com/alex1s/dilithium.git shuffling SOMETHING_NOT_DEFINED_HOPEFULLY=WHATEVER
# DEBUG:io.github.alex1s.python-dilithium:CompletedProcess(args=['git', 'clone', '--branch', 'shuffling', 'https://github.com/alex1s/dilithium.git', '/tmp/python-dilithium-git-repo'], returncode=128, stdout=b'', stderr=b"Schwerwiegend: Zielpfad '/tmp/python-dilithium-git-repo' existiert bereits und ist kein leeres Verzeichnis.\n")
# DEBUG:io.github.alex1s.python-dilithium:make_shared = {make_shared}
# DEBUG:io.github.alex1s.python-dilithium:CompletedProcess(args=['/usr/bin/env', 'make', 'shared', 'CFLAGS=-Wl,-undefined,dynamic_lookup -march=native'], returncode=0, stdout=b"make: Nothing to be done for `shared'.\n", stderr=b'')
# DEBUG:io.github.alex1s.python-dilithium:CompletedProcess(args=['/usr/bin/env', 'gcc', '-shared', '-fPIC', '-Wl,-undefined,dynamic_lookup', '-DSOMETHING_NOT_DEFINED_HOPEFULLY=WHATEVER', '-o', 'libpqcrystals_randombytes_ref.so', 'randombytes.c'], returncode=0, stdout=b'', stderr=b'')
# DEBUG:io.github.alex1s.python-dilithium:CompletedProcess(args=['/usr/bin/env', 'make', 'shared', 'CFLAGS=-Wl,-undefined,dynamic_lookup -march=native'], returncode=0, stdout=b"make: Nothing to be done for `shared'.\n", stderr=b'')
# DEBUG:io.github.alex1s.python-dilithium:Loading libpqcrystals_fips202_avx2
# DEBUG:io.github.alex1s.python-dilithium:Loading libpqcrystals_fips202_ref
# DEBUG:io.github.alex1s.python-dilithium:Loading libpqcrystals_randombytes_ref
# DEBUG:io.github.alex1s.python-dilithium:Loading libpqcrystals_aes256ctr_ref
# DEBUG:io.github.alex1s.python-dilithium:Loading libpqcrystals_fips202x4_avx2
# DEBUG:io.github.alex1s.python-dilithium:Loading libpqcrystals_aes256ctr_avx2
# DEBUG:io.github.alex1s.python-dilithium:Loading libpqcrystals_dilithium5_ref
# DEBUG:io.github.alex1s.python-dilithium:Loading libpqcrystals_dilithium3aes_ref
# DEBUG:io.github.alex1s.python-dilithium:Loading libpqcrystals_dilithium3aes_avx2
# DEBUG:io.github.alex1s.python-dilithium:Loading libpqcrystals_dilithium5aes_ref
# DEBUG:io.github.alex1s.python-dilithium:Loading libpqcrystals_dilithium2aes_avx2
# DEBUG:io.github.alex1s.python-dilithium:Loading libpqcrystals_dilithium5aes_avx2
# DEBUG:io.github.alex1s.python-dilithium:Loading libpqcrystals_dilithium2_ref
# DEBUG:io.github.alex1s.python-dilithium:Loading libpqcrystals_dilithium3_avx2
# DEBUG:io.github.alex1s.python-dilithium:Loading libpqcrystals_dilithium3_ref
# DEBUG:io.github.alex1s.python-dilithium:Loading libpqcrystals_dilithium2_avx2
# DEBUG:io.github.alex1s.python-dilithium:Loading libpqcrystals_dilithium2aes_ref
# DEBUG:io.github.alex1s.python-dilithium:Loading libpqcrystals_dilithium5_avx2
# DEBUG:io.github.alex1s.python-dilithium:CompletedProcess(args=['/usr/bin/env', 'gcc', '-x', 'c', '-DDILITHIUM_MODE=2', '-o', 'dump_params', '-'], returncode=0, stdout=b'', stderr=b'')
# DEBUG:io.github.alex1s.python-dilithium:{'SEEDBYTES': 32, 'CRHBYTES': 64, 'N': 256, 'Q': 8380417, 'D': 13, 'ROOT_OF_UNITY': 1753, 'K': 4, 'L': 4, 'ETA': 2, 'TAU': 39, 'BETA': 78, 'GAMMA1': 131072, 'GAMMA2': 95232, 'OMEGA': 80, 'POLYT1_PACKEDBYTES': 320, 'POLYT0_PACKEDBYTES': 416, 'POLYVECH_PACKEDBYTES': 84, 'POLYZ_PACKEDBYTES': 576, 'POLYW1_PACKEDBYTES': 192, 'POLYETA_PACKEDBYTES': 96, 'CRYPTO_PUBLICKEYBYTES': 1312, 'CRYPTO_SECRETKEYBYTES': 2528, 'CRYPTO_BYTES': 2420}
# DEBUG:io.github.alex1s.python-dilithium:CompletedProcess(args=['/usr/bin/env', 'gcc', '-x', 'c', '-DDILITHIUM_MODE=3', '-o', 'dump_params', '-'], returncode=0, stdout=b'', stderr=b'')
# DEBUG:io.github.alex1s.python-dilithium:{'SEEDBYTES': 32, 'CRHBYTES': 64, 'N': 256, 'Q': 8380417, 'D': 13, 'ROOT_OF_UNITY': 1753, 'K': 6, 'L': 5, 'ETA': 4, 'TAU': 49, 'BETA': 196, 'GAMMA1': 524288, 'GAMMA2': 261888, 'OMEGA': 55, 'POLYT1_PACKEDBYTES': 320, 'POLYT0_PACKEDBYTES': 416, 'POLYVECH_PACKEDBYTES': 61, 'POLYZ_PACKEDBYTES': 640, 'POLYW1_PACKEDBYTES': 128, 'POLYETA_PACKEDBYTES': 128, 'CRYPTO_PUBLICKEYBYTES': 1952, 'CRYPTO_SECRETKEYBYTES': 4000, 'CRYPTO_BYTES': 3293}
# DEBUG:io.github.alex1s.python-dilithium:CompletedProcess(args=['/usr/bin/env', 'gcc', '-x', 'c', '-DDILITHIUM_MODE=5', '-o', 'dump_params', '-'], returncode=0, stdout=b'', stderr=b'')
# DEBUG:io.github.alex1s.python-dilithium:{'SEEDBYTES': 32, 'CRHBYTES': 64, 'N': 256, 'Q': 8380417, 'D': 13, 'ROOT_OF_UNITY': 1753, 'K': 8, 'L': 7, 'ETA': 2, 'TAU': 60, 'BETA': 120, 'GAMMA1': 524288, 'GAMMA2': 261888, 'OMEGA': 75, 'POLYT1_PACKEDBYTES': 320, 'POLYT0_PACKEDBYTES': 416, 'POLYVECH_PACKEDBYTES': 83, 'POLYZ_PACKEDBYTES': 640, 'POLYW1_PACKEDBYTES': 128, 'POLYETA_PACKEDBYTES': 96, 'CRYPTO_PUBLICKEYBYTES': 2592, 'CRYPTO_SECRETKEYBYTES': 4864, 'CRYPTO_BYTES': 4595}
# DEBUG:matplotlib:matplotlib data path: /Users/alexis/git/chipwhisperer/jupyter-dilithium/.venv/lib/python3.11/site-packages/matplotlib/mpl-data
# DEBUG:matplotlib:CONFIGDIR=/Users/alexis/.matplotlib
# DEBUG:matplotlib:interactive is False
# DEBUG:matplotlib:platform is darwin
# DEBUG:matplotlib:CACHEDIR=/Users/alexis/.matplotlib
# DEBUG:matplotlib.font_manager:Using fontManager instance from /Users/alexis/.matplotlib/fontlist-v330.json

# %%
#from IPython.display import display, HTML
#display(HTML("<style>.container { width:100% !important; }</style>"))

__LOGGER = logging.getLogger(__name__)

d = Dilithium(2)

# %%
FILE_NAME = 'gc.results.pickled.signature-attacks-2023-03-16_00-14-39.pickle'

# %%
with open(FILE_NAME, "rb") as f:
    gr = pickle.load(f)

# %%
with open(FILE_NAME, "rb") as f:
    gr = pickle.load(f)

# get rid of constant, that shit is annoying ...
constant = gr.result_dict['constant'][0]['metadata']
del gr.result_dict['constant']
gr.groups = [group for group in gr.groups if group != 'constant']

# recreate the GlitchController object ...
gc = glitch.GlitchController(gr.groups, gr.parameters)

# add the results
for group, results in gr.result_dict.items():
    for result in results:
        parameters = result["parameters"]
        strdesc = result["strdesc"]
        metadata = result["metadata"]
        
        try:
            gc.add(group, parameters, strdesc, metadata)
        except TypeError:  # will be raised if we do not "gc.display_stats"; but not a problem: still collects all data
            pass

# fix that params are a tuple and not a list
for group, results in gc.results.result_dict.items():
    for result in results:
        result['parameters'] = tuple(result['parameters'])
        
# set ranges ...          
result_list_full = [result for group, result_list in gc.results.result_dict.items() if group != 'constant' for result in result_list]
if len(result_list_full) == 0:
    raise RuntimeError("GlitchResults object contains no results!")
for parameter_index, parameter in enumerate(gc.parameters):
    all_distinct_parameters = set(map(lambda result: result['parameters'][parameter_index], result_list_full))
    parameter_min = min(all_distinct_parameters)
    parameter_max = max(all_distinct_parameters)
    gc.set_range(parameter, parameter_min, parameter_max)

# We successfully recreate the GlitchController object!
    
def display_stats() -> None:
    """
    Custom version of display_stats because we do not know the 'current' set parameters.
    Thus we do display the current set parameters but the min and max of each parameter.
    """
    gc.widget_list_groups = [widgets.IntText(
        value=len(gc.results.__dict__['result_dict'][group]),
        description=f"{group} count:",
        disabled=True,
        layout=widgets.Layout(width='100%')
    ) for group in gc.groups]
    gc.widget_list_parameter = [widgets.FloatRangeSlider(
        value=[gc.parameter_min[i], gc.parameter_max[i]],
        min=gc.parameter_min[i],
        max=gc.parameter_max[i],
        description=f'{parameter} setting',
        disabled=True,
        readout_format='f',
        layout=widgets.Layout(width='100%')
    ) for i, parameter in enumerate(gc.parameters)]

    display(*(gc.widget_list_groups + gc.widget_list_parameter))

display_stats()
# Out:
# IntText(value=9, description='0 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='0 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=69, description='0 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='0 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='0 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='0 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=9, description='1 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='1 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=169, description='1 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='1 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='1 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='1 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=9, description='2 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='2 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=120, description='2 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1, description='2 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='2 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='2 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=9, description='3 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='3 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=61, description='3 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='3 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='3 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='3 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=9, description='4 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='4 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=130, description='4 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='4 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='4 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='4 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=10, description='5 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='5 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=107, description='5 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='5 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='5 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='5 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=10, description='6 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='6 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=247, description='6 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='6 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='6 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='6 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=10, description='7 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='7 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=140, description='7 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='7 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='7 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='7 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=10, description='8 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='8 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=109, description='8 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='8 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='8 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='8 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=10, description='9 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='9 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=154, description='9 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1, description='9 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='9 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='9 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=10, description='10 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='10 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=84, description='10 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='10 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='10 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='10 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=11, description='11 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='11 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=123, description='11 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='11 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='11 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='11 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=11, description='12 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='12 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=204, description='12 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='12 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='12 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='12 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=11, description='13 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='13 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=178, description='13 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='13 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='13 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='13 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=12, description='14 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='14 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=115, description='14 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='14 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='14 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='14 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=12, description='15 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='15 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=260, description='15 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='15 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='15 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='15 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=12, description='16 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='16 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=191, description='16 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='16 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='16 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='16 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=12, description='17 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='17 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=164, description='17 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='17 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='17 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='17 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=12, description='18 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='18 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=137, description='18 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='18 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='18 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='18 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=13, description='19 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='19 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=136, description='19 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1, description='19 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='19 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='19 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=13, description='20 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='20 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=167, description='20 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='20 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='20 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='20 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=13, description='21 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='21 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=166, description='21 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1, description='21 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='21 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='21 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=14, description='22 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='22 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=276, description='22 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='22 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='22 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='22 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=14, description='23 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='23 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=292, description='23 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='23 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='23 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='23 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=14, description='24 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='24 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=333, description='24 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1, description='24 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='24 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='24 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=15, description='25 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='25 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=147, description='25 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='25 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='25 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='25 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=15, description='26 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='26 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=243, description='26 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='26 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='26 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='26 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=15, description='27 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='27 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=169, description='27 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='27 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='27 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='27 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=16, description='28 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='28 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=255, description='28 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='28 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='28 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='28 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=16, description='29 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='29 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=193, description='29 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1, description='29 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='29 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='29 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=17, description='30 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='30 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=167, description='30 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='30 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='30 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='30 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=17, description='31 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='31 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=144, description='31 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1, description='31 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='31 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='31 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=17, description='32 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='32 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=228, description='32 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='32 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='32 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='32 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=17, description='33 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='33 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=178, description='33 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=2, description='33 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='33 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='33 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=18, description='34 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='34 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=438, description='34 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1, description='34 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='34 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='34 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=19, description='35 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='35 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=254, description='35 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='35 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='35 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='35 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=20, description='36 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='36 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=295, description='36 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='36 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='36 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='36 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=21, description='37 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='37 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=421, description='37 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='37 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='37 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='37 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=22, description='38 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='38 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=355, description='38 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=2, description='38 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='38 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='38 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=23, description='39 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='39 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=344, description='39 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='39 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='39 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='39 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=23, description='40 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='40 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=618, description='40 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='40 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='40 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='40 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=24, description='41 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='41 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=245, description='41 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='41 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='41 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='41 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=26, description='42 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='42 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=491, description='42 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='42 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='42 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='42 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=26, description='43 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='43 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=490, description='43 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='43 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='43 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='43 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=28, description='44 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='44 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=250, description='44 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='44 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='44 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='44 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=30, description='45 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='45 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=377, description='45 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='45 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='45 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='45 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=31, description='46 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='46 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=808, description='46 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='46 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='46 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='46 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=31, description='47 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=2, description='47 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=730, description='47 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='47 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='47 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='47 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='48 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=35, description='48 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=642, description='48 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1, description='48 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='48 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='48 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='49 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=39, description='49 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=761, description='49 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='49 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='49 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='49 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='50 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=41, description='50 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=814, description='50 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='50 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='50 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='50 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='51 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=44, description='51 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1043, description='51 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1, description='51 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='51 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='51 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='52 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=46, description='52 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=759, description='52 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1, description='52 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='52 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='52 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='53 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=52, description='53 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1338, description='53 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='53 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='53 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='53 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='54 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=57, description='54 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1341, description='54 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='54 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='54 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='54 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='55 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=65, description='55 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1532, description='55 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='55 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='55 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='55 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='56 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=74, description='56 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1169, description='56 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='56 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='56 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='56 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='57 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=84, description='57 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1556, description='57 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1, description='57 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='57 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='57 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='58 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=101, description='58 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1601, description='58 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=2, description='58 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='58 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='58 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='59 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=124, description='59 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=2826, description='59 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=3, description='59 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='59 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='59 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='60 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=168, description='60 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=3089, description='60 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=1, description='60 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='60 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='60 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='61 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=218, description='61 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=3799, description='61 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=4, description='61 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='61 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='61 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='62 zeros count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=370, description='62 other count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=5455, description='62 to count count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=9, description='62 to time count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='62 exc sign count:', disabled=True, layout=Layout(width='100%'))
# IntText(value=0, description='62 exc get_sig count:', disabled=True, layout=Layout(width='100%'))
# FloatRangeSlider(value=(55.0, 3899.0), description='ext_offset setting', disabled=True, layout=Layout(width='1…
# FloatRangeSlider(value=(0.390625, 0.390625), description='offset setting', disabled=True, layout=Layout(width=…
# FloatRangeSlider(value=(1.5625, 1.5625), description='width setting', disabled=True, layout=Layout(width='100%…
# FloatRangeSlider(value=(1.0, 1.0), description='repeat setting', disabled=True, layout=Layout(width='100%'), m…
# FloatRangeSlider(value=(0.0, 5833.0), description='message setting', disabled=True, layout=Layout(width='100%'…
# FloatRangeSlider(value=(1.0, 1.0), description='redo setting', disabled=True, layout=Layout(width='100%'), max…

# %%
def try_recover(packed_sigs: [bytes]) -> [dict]:
    sigs_faulted_unpacked = list(map(lambda sig_packed: d._unpack_sig_full(sig_packed), packed_sigs))
    from dilithium_solver.signature import Signature, calculate_c_matrix_np
    from dilithium_solver.recover_s_1_entry import recover_s_1_entry
    from dilithium_solver.parameters import Parameters
    from dilithium_solver.result import ResultKeys
    import gurobipy as gp

    gp.setParam('OutputFlag', 0)
    params = Parameters.get_nist_security_level(d.nist_security_level)

    sigs = list(map(
        lambda sig_faulted: Signature(
            sig_faulted[1],
            sig_faulted[0],
            calculate_c_matrix_np(sig_faulted[0], params)
        ), sigs_faulted_unpacked))
    s_1_entry_index = 0


    s_1 = d._unpack_sk(constant['secret_key'])[4]
    timeout = 10
    threshold = d.beta
    recovered_s = np.zeros((d.l, d.n))
    results = []
    for i in range(len(sigs_faulted_unpacked[0][1])): # long version of saying "l"
        result = recover_s_1_entry(sigs, i, s_1, params, 142387, timeout, threshold) # this number is not relevant
        results.append(result)
    return results

# %%
df = pd.json_normalize([{**result, 'group': group}
                        for group, result_list in gc.results.result_dict.items() if group != 'constant'
                        for result in result_list
                       ])

# rename column names
df.columns = [column.split('.')[-1] for column in df.columns]

# lets ignore groups; if it has a sig it is good, otherwise not
del df['group']
# who needs message bytes anyhow ...
del df['message_bytes']
# message int is already in the parameters ...
del df['message_int']
# strdesc; i never used thus
del df['strdesc']
# reset_duration_ns is interesting for optimizations, but we do not need that right now ...
del df['reset_duration_ns']

# lets keep only the varying parameters: ext_offset and message
for param in ['ext_offset', 'message']:
    df[param] = df['parameters'].apply(lambda p: p[gc.parameters.index(param)])
del df['parameters']

# add poly_index
df['poly_index'] = df['ext_offset'].apply(lambda ext_offset: constant['magic_numbers'].index(ext_offset))

# add timing information
df['time'] = df.apply(lambda row: row['timestamp'] - constant['start_times'][row['poly_index']], axis=1)
df['time'] = pd.to_timedelta(df['time'], unit='s')
del df['timestamp']

# well actually poly_index and message is a primary key; so we can use that and delete global_counter
# note that ext_offset to poly_index is a 1 to 1 mapping
del df['global_counter']
del df['ext_offset']
df.set_index(['poly_index', 'message'], inplace=True)

df['unpacked'] = df['packed'].apply(lambda packed: np.nan if pd.isnull(packed) else d._unpack_sig_full(packed))
df[['c', 'z', 'h']] = df['unpacked'].apply(lambda x: pd.Series(x))
del df['h']
del df['unpacked']

df['abs_z_le_beta'] = df['z'].apply(lambda z: np.nan if type(z) is not np.ndarray else np.count_nonzero(np.abs(z) <= d.beta))
del df['c']
del df['z']

min_num_zero = min(df['abs_z_le_beta'].dropna())
assert min_num_zero >= 4, "some sigs have no fault?"
print(f'Maybe all signatures that appear in this dataset have at least {min_num_zero} zero coefficients.')

df.sort_index(inplace=True)

new = df.reset_index().groupby('poly_index').agg({'packed': lambda series: (~pd.isna(series)).cumsum()}).explode('packed', ignore_index=True)
new_series_list = new['packed'].astype(np.uint).tolist()
df['num_sigs_per_pi'] = new_series_list

df
# Out:
# Maybe all signatures that appear in this dataset have at least 4.0 zero coefficients.
#                                                                packed
# poly_index message
# 0          0                                                      NaN  \
#            1                                                      NaN
#            2                                                      NaN
#            3                                                      NaN
#            4                                                      NaN
# ...                                                               ...
# 62         5829                                                   NaN
#            5830                                                   NaN
#            5831                                                   NaN
#            5832                                                   NaN
#            5833     b'\xaer\xab\xfa\x84\xefI\x9a$E(\x10CmGv\x89\xa...
#
#                     trig_count                      time  abs_z_le_beta
# poly_index message
# 0          0             15904 0 days 00:00:00.671444178            NaN  \
#            1             15965 0 days 00:00:01.377696991            NaN
#            2             15904 0 days 00:00:02.082550764            NaN
#            3             15904 0 days 00:00:02.830159664            NaN
#            4             15904 0 days 00:00:03.535058975            NaN
# ...                        ...                       ...            ...
# 62         5829          15965 0 days 01:16:56.371078253            NaN
#            5830          19817 0 days 01:16:57.326249123            NaN
#            5831          15965 0 days 01:16:58.053329229            NaN
#            5832          15965 0 days 01:16:58.738143682            NaN
#            5833          15841 0 days 01:16:59.993063211            6.0
#
#                     num_sigs_per_pi
# poly_index message
# 0          0                      0
#            1                      0
#            2                      0
#            3                      0
#            4                      0
# ...                             ...
# 62         5829                 369
#            5830                 369
#            5831                 369
#            5832                 369
#            5833                 370
#
# [42018 rows x 5 columns]

# %%
df_zeros = df.groupby(level=0)['abs_z_le_beta'].agg(lambda series: series.value_counts().to_dict())
with pd.option_context('display.max_rows', None, 'max_colwidth', 100):
    display(df_zeros)
#diffs = df_zeros.shift(1) - df_zeros
#display(diffs)
#display(diffs.value_counts())
# Out:
# poly_index
# 0                                         {253.0: 7, 254.0: 2}
# 1                     {249.0: 4, 251.0: 2, 250.0: 2, 252.0: 1}
# 2                               {245.0: 5, 246.0: 3, 247.0: 1}
# 3                     {241.0: 5, 242.0: 2, 243.0: 1, 240.0: 1}
# 4                                         {237.0: 6, 238.0: 3}
# 5                     {233.0: 5, 234.0: 2, 235.0: 2, 232.0: 1}
# 6                               {229.0: 4, 230.0: 3, 231.0: 3}
# 7                     {225.0: 6, 226.0: 2, 224.0: 1, 227.0: 1}
# 8                     {222.0: 4, 221.0: 4, 225.0: 1, 223.0: 1}
# 9                               {217.0: 5, 218.0: 4, 216.0: 1}
# 10                              {213.0: 5, 214.0: 4, 215.0: 1}
# 11                              {209.0: 9, 210.0: 1, 208.0: 1}
# 12                              {205.0: 6, 206.0: 4, 207.0: 1}
# 13                                        {201.0: 8, 202.0: 3}
# 14                              {197.0: 7, 198.0: 3, 199.0: 2}
# 15                    {193.0: 7, 194.0: 2, 195.0: 2, 196.0: 1}
# 16                                        {189.0: 8, 190.0: 4}
# 17                    {185.0: 5, 186.0: 4, 184.0: 2, 187.0: 1}
# 18                    {181.0: 7, 182.0: 2, 180.0: 2, 184.0: 1}
# 19                    {178.0: 7, 177.0: 3, 179.0: 2, 181.0: 1}
# 20                    {173.0: 7, 174.0: 4, 172.0: 1, 177.0: 1}
# 21                              {169.0: 6, 170.0: 4, 171.0: 3}
# 22                             {165.0: 10, 166.0: 3, 167.0: 1}
# 23                                       {161.0: 10, 162.0: 4}
# 24                              {157.0: 6, 158.0: 6, 159.0: 2}
# 25                              {153.0: 8, 154.0: 5, 155.0: 2}
# 26                    {149.0: 9, 151.0: 3, 150.0: 2, 148.0: 1}
# 27                             {145.0: 10, 146.0: 3, 147.0: 2}
# 28                             {141.0: 13, 142.0: 2, 143.0: 1}
# 29                    {137.0: 7, 138.0: 5, 139.0: 2, 136.0: 2}
# 30                    {134.0: 7, 133.0: 7, 132.0: 2, 137.0: 1}
# 31          {129.0: 7, 130.0: 4, 131.0: 3, 128.0: 2, 133.0: 1}
# 32                    {125.0: 8, 126.0: 5, 124.0: 3, 127.0: 1}
# 33                              {121.0: 9, 122.0: 6, 123.0: 2}
# 34                             {117.0: 14, 118.0: 3, 116.0: 1}
# 35                             {114.0: 10, 113.0: 8, 115.0: 1}
# 36                             {109.0: 10, 110.0: 9, 108.0: 1}
# 37                             {105.0: 11, 106.0: 7, 107.0: 3}
# 38                   {101.0: 13, 102.0: 4, 103.0: 3, 100.0: 2}
# 39                                {97.0: 12, 98.0: 7, 99.0: 4}
# 40                       {93.0: 11, 95.0: 6, 94.0: 5, 92.0: 1}
# 41                       {89.0: 12, 90.0: 9, 91.0: 2, 88.0: 1}
# 42                       {85.0: 19, 86.0: 5, 87.0: 1, 84.0: 1}
# 43                      {82.0: 13, 81.0: 10, 80.0: 2, 83.0: 1}
# 44                                        {77.0: 16, 78.0: 12}
# 45                       {73.0: 18, 74.0: 9, 75.0: 2, 76.0: 1}
# 46                                         {69.0: 22, 70.0: 9}
# 47                      {65.0: 15, 66.0: 11, 67.0: 5, 64.0: 2}
# 48                      {61.0: 19, 62.0: 10, 63.0: 4, 60.0: 2}
# 49                      {57.0: 22, 58.0: 12, 59.0: 3, 56.0: 2}
# 50                      {53.0: 23, 54.0: 12, 55.0: 4, 52.0: 2}
# 51                      {49.0: 23, 50.0: 17, 48.0: 3, 51.0: 1}
# 52              {45.0: 28, 46.0: 9, 47.0: 7, 48.0: 1, 49.0: 1}
# 53                      {41.0: 27, 42.0: 17, 43.0: 5, 40.0: 3}
# 54             {38.0: 23, 37.0: 23, 39.0: 4, 36.0: 4, 40.0: 3}
# 55    {33.0: 38, 34.0: 17, 35.0: 5, 32.0: 2, 36.0: 2, 37.0: 1}
# 56                     {29.0: 34, 30.0: 26, 31.0: 11, 32.0: 3}
# 57             {25.0: 40, 26.0: 30, 27.0: 8, 24.0: 4, 28.0: 2}
# 58             {21.0: 54, 22.0: 36, 23.0: 7, 20.0: 2, 24.0: 2}
# 59            {17.0: 64, 18.0: 43, 19.0: 10, 16.0: 5, 20.0: 2}
# 60            {13.0: 90, 14.0: 59, 15.0: 10, 12.0: 7, 16.0: 2}
# 61    {9.0: 112, 10.0: 71, 11.0: 24, 12.0: 7, 13.0: 2, 8.0: 2}
# 62      {5.0: 186, 6.0: 124, 7.0: 39, 8.0: 14, 4.0: 6, 9.0: 1}
# Name: abs_z_le_beta, dtype: object

# %%
percent_keep = .61
limits = np.floor(df.reset_index().groupby('poly_index')['num_sigs_per_pi'].max() * percent_keep)
display(limits)
keep_mask_le = df.reset_index()['num_sigs_per_pi'] <= df.reset_index()['poly_index'].map(limits)  # only include the signatures equal or same to limit (i.e. we have limiut many signaturs)
keep_mask_same_non_nan = (df.reset_index()['num_sigs_per_pi'] != df.reset_index()['poly_index'].map(limits)) | (~pd.isna(df.reset_index()['packed']))  # if same, then has to be not nan
keep_mask = keep_mask_le & keep_mask_same_non_nan
display(keep_mask)
df_keep = df[keep_mask.tolist()]
df_keep
# Out:
# poly_index
# 0       5.0
# 1       5.0
# 2       5.0
# 3       5.0
# 4       5.0
#       ...
# 58     61.0
# 59     75.0
# 60    102.0
# 61    132.0
# 62    225.0
# Name: num_sigs_per_pi, Length: 63, dtype: float64
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#          ...
# 42013    False
# 42014    False
# 42015    False
# 42016    False
# 42017    False
# Length: 42018, dtype: bool
#                                                                packed
# poly_index message
# 0          0                                                      NaN  \
#            1                                                      NaN
#            2                                                      NaN
#            3                                                      NaN
#            4                                                      NaN
# ...                                                               ...
# 62         3686     b'\xa0\x9d\x1e\x073]\x83\xd6\x01\xde 3\x9a4W\x...
#            3687                                                   NaN
#            3688                                                   NaN
#            3689                                                   NaN
#            3690     b'\xcfJ%$\x04[\xcfFW\xa3G`}\xc5\xb8\xc3\xcc\x9...
#
#                     trig_count                      time  abs_z_le_beta
# poly_index message
# 0          0             15904 0 days 00:00:00.671444178            NaN  \
#            1             15965 0 days 00:00:01.377696991            NaN
#            2             15904 0 days 00:00:02.082550764            NaN
#            3             15904 0 days 00:00:02.830159664            NaN
#            4             15904 0 days 00:00:03.535058975            NaN
# ...                        ...                       ...            ...
# 62         3686          15841 0 days 00:48:35.085243702            5.0
#            3687          15904 0 days 00:48:35.781520844            NaN
#            3688          15904 0 days 00:48:36.475890160            NaN
#            3689          18815 0 days 00:48:37.390022755            NaN
#            3690          15841 0 days 00:48:38.609140158            6.0
#
#                     num_sigs_per_pi
# poly_index message
# 0          0                      0
#            1                      0
#            2                      0
#            3                      0
#            4                      0
# ...                             ...
# 62         3686                 224
#            3687                 224
#            3688                 224
#            3689                 224
#            3690                 225
#
# [25488 rows x 5 columns]

# %%
#with pd.option_context('display.max_rows', None):
#    display(df_keep)

# %%
pd.set_option('display.max_columns', None, 'max_colwidth', 30)

# %%
df_grouped = df_keep.copy()

def value_counts_uint(series):
    vc = series.value_counts()
    vc.index = vc.index.astype(np.uint)
    return vc

df_grouped['success_rate'] = df_grouped['packed']
df_grouped['num_good'] = df_grouped['packed']
df_grouped['num_bad'] = df_grouped['packed']
df_grouped = df_grouped.groupby(level='poly_index').agg({
    'abs_z_le_beta': lambda series: value_counts_uint(series).to_dict(),
    'time': max,
    'packed': lambda series: set(series.dropna()),
    'success_rate': lambda series: series.count() / (series.count() + series.isna().sum()),
    'num_good': lambda series: series.count(),
    'num_bad': lambda series: series.isna().sum()
})
df_grouped['num_distinct_sigs'] = df_grouped['packed'].apply(len)

df_grouped = df_grouped.rename(columns={'abs_z_le_beta': 'abs_z_le_beta_vc'})

display(df_grouped)

print('Recovering key, this may take a while ....')
df_grouped['result'] = df_grouped['packed'].apply(try_recover)
print('Done trying to recover!')


df_grouped
# Out:
#                          abs_z_le_beta_vc                      time
# poly_index
# 0                        {253: 4, 254: 1} 0 days 00:00:42.038979053  \
# 1                {249: 3, 251: 1, 252: 1} 0 days 00:00:46.006530046
# 2                {246: 2, 245: 2, 247: 1} 0 days 00:01:01.733885288
# 3                        {241: 4, 242: 1} 0 days 00:00:38.796548367
# 4                        {237: 4, 238: 1} 0 days 00:01:00.558928728
# ...                                   ...                       ...
# 58          {21: 32, 22: 22, 23: 5, 20... 0 days 00:14:01.127526759
# 59          {17: 40, 18: 22, 19: 8, 16... 0 days 00:22:17.794250965
# 60          {13: 54, 14: 34, 15: 7, 12... 0 days 00:26:33.382155895
# 61          {9: 63, 10: 43, 11: 16, 12... 0 days 00:30:31.847288609
# 62          {5: 116, 6: 74, 7: 23, 8: ... 0 days 00:48:38.609140158
#
#                                    packed  success_rate  num_good  num_bad
# poly_index
# 0           {b'\xeb~\xf3\xb3\xd3&\x9e\...      0.094340         5       48  \
# 1           {b'<\x1f.\x80\xd0\x12\xa7\...      0.089286         5       51
# 2           {b'\x1d\x10\xb8\xf80\x03\x...      0.065789         5       71
# 3           {b'\x1f\xc2\x8a\xadin[\x12...      0.104167         5       43
# 4           {b'\x7f\xe0.n\xed\xe3[]=\x...      0.066667         5       70
# ...                                   ...           ...       ...      ...
# 58          {b'pN\xcb\xa8\xc7\x82\xcf\...      0.058485        61      982
# 59          {b'\x9eM\x84\xa4[\x1cu\x89...      0.044405        75     1614
# 60          {b'7\xf8\xd7\x9b*\xaa\x1am...      0.050370       102     1923
# 61          {b'\x02=\x0f\x8e\xc7\x80\x...      0.056848       132     2190
# 62          {b'\xe5IH\xcd!\xa7\xb5V\xf...      0.060959       225     3466
#
#             num_distinct_sigs
# poly_index
# 0                           5
# 1                           5
# 2                           5
# 3                           5
# 4                           5
# ...                       ...
# 58                         61
# 59                         75
# 60                        102
# 61                        132
# 62                        225
#
# [63 rows x 7 columns]
# Recovering key, this may take a while ....
# Set parameter Username
# INFO:gurobipy.gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2024-03-29
# INFO:gurobipy.gurobipy:Academic license - for non-commercial use only - expires 2024-03-29
# INFO:root:Before filter: 1280; after filter: 333; delta: 947; threshold: 78
# INFO:root:Total filtered: 333; true: 142387; false: -142054; false-positive rate: -42658.85885885886%; probability: nan
# Set parameter Username
# INFO:gurobipy.gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2024-03-29
# INFO:gurobipy.gurobipy:Academic license - for non-commercial use only - expires 2024-03-29
# Set parameter TimeLimit to value 10
# INFO:gurobipy.gurobipy:Set parameter TimeLimit to value 10
# Set parameter Threads to value 4
# INFO:gurobipy.gurobipy:Set parameter Threads to value 4
# INFO:root:Starting recovery of an entry. Will timeout after 10s. Current datetime is: 2023-04-05 00:51:16.441910
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:
# CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# INFO:gurobipy.gurobipy:CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:
# Optimize a model with 666 rows, 589 columns and 26640 nonzeros
# INFO:gurobipy.gurobipy:Optimize a model with 666 rows, 589 columns and 26640 nonzeros
# Model fingerprint: 0x949dd6c8
# INFO:gurobipy.gurobipy:Model fingerprint: 0x949dd6c8
# Variable types: 0 continuous, 589 integer (333 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 589 integer (333 binary)
# Coefficient statistics:
# INFO:gurobipy.gurobipy:Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
# INFO:gurobipy.gurobipy:  Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 1e+00]
# INFO:gurobipy.gurobipy:  Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
# INFO:gurobipy.gurobipy:  Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+05, 1e+05]
# INFO:gurobipy.gurobipy:  RHS range        [1e+05, 1e+05]
# Found heuristic solution: objective 10.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 10.0000000
# Presolve time: 0.04s
# INFO:gurobipy.gurobipy:Presolve time: 0.04s
# Presolved: 666 rows, 589 columns, 26640 nonzeros
# INFO:gurobipy.gurobipy:Presolved: 666 rows, 589 columns, 26640 nonzeros
# Variable types: 0 continuous, 589 integer (333 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 589 integer (333 binary)
# Found heuristic solution: objective 28.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 28.0000000
# INFO:gurobipy.gurobipy:
# Root relaxation: objective 3.330000e+02, 792 iterations, 0.15 seconds (0.18 work units)
# INFO:gurobipy.gurobipy:Root relaxation: objective 3.330000e+02, 792 iterations, 0.15 seconds (0.18 work units)
# INFO:root:Candidate is correct with same sign
# INFO:gurobipy.gurobipy:
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy.gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy:
# *    0     0               0     333.0000000  333.00000  0.00%     -    0s
# INFO:gurobipy.gurobipy:*    0     0               0     333.0000000  333.00000  0.00%     -    0s
# INFO:root:Candidate is correct with same sign
# INFO:gurobipy.gurobipy:
# Explored 1 nodes (792 simplex iterations) in 0.30 seconds (0.21 work units)
# INFO:gurobipy.gurobipy:Explored 1 nodes (792 simplex iterations) in 0.30 seconds (0.21 work units)
# Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:
# Solution count 3: 333 28 10
# INFO:gurobipy.gurobipy:Solution count 3: 333 28 10
# INFO:gurobipy.gurobipy:
# Solve interrupted
# INFO:gurobipy.gurobipy:Solve interrupted
# Best objective 3.330000000000e+02, best bound 3.330000000000e+02, gap 0.0000%
# INFO:gurobipy.gurobipy:Best objective 3.330000000000e+02, best bound 3.330000000000e+02, gap 0.0000%
# INFO:gurobipy.gurobipy:
# User-callback calls 190, time in user-callback 0.02 sec
# INFO:gurobipy.gurobipy:User-callback calls 190, time in user-callback 0.02 sec
# DEBUG:root:Gurobi result status: "INTERRUPTED"
# INFO:root:We used 333.0 zero coefficients in y to recover the secret key.
# INFO:root:Recovery took 0.3127110004425049 seconds.
# INFO:root:Successfully recovered s_1 entry!
# INFO:root:Before filter: 1280; after filter: 317; delta: 963; threshold: 78
# INFO:root:Total filtered: 317; true: 142387; false: -142070; false-positive rate: -44817.03470031546%; probability: nan
# Set parameter Username
# INFO:gurobipy.gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2024-03-29
# INFO:gurobipy.gurobipy:Academic license - for non-commercial use only - expires 2024-03-29
# Set parameter TimeLimit to value 10
# INFO:gurobipy.gurobipy:Set parameter TimeLimit to value 10
# Set parameter Threads to value 4
# INFO:gurobipy.gurobipy:Set parameter Threads to value 4
# INFO:root:Starting recovery of an entry. Will timeout after 10s. Current datetime is: 2023-04-05 00:51:16.825614
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:
# CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# INFO:gurobipy.gurobipy:CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:
# Optimize a model with 634 rows, 573 columns and 25360 nonzeros
# INFO:gurobipy.gurobipy:Optimize a model with 634 rows, 573 columns and 25360 nonzeros
# Model fingerprint: 0x08ae98d7
# INFO:gurobipy.gurobipy:Model fingerprint: 0x08ae98d7
# Variable types: 0 continuous, 573 integer (317 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 573 integer (317 binary)
# Coefficient statistics:
# INFO:gurobipy.gurobipy:Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
# INFO:gurobipy.gurobipy:  Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 1e+00]
# INFO:gurobipy.gurobipy:  Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
# INFO:gurobipy.gurobipy:  Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+05, 1e+05]
# INFO:gurobipy.gurobipy:  RHS range        [1e+05, 1e+05]
# Found heuristic solution: objective 4.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 4.0000000
# Presolve time: 0.04s
# INFO:gurobipy.gurobipy:Presolve time: 0.04s
# Presolved: 634 rows, 573 columns, 25360 nonzeros
# INFO:gurobipy.gurobipy:Presolved: 634 rows, 573 columns, 25360 nonzeros
# Variable types: 0 continuous, 573 integer (317 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 573 integer (317 binary)
# Found heuristic solution: objective 27.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 27.0000000
# INFO:gurobipy.gurobipy:
# Root relaxation: objective 3.170000e+02, 661 iterations, 0.14 seconds (0.13 work units)
# INFO:gurobipy.gurobipy:Root relaxation: objective 3.170000e+02, 661 iterations, 0.14 seconds (0.13 work units)
# INFO:root:Candidate is correct with same sign
# INFO:gurobipy.gurobipy:
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy.gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy:
# *    0     0               0     317.0000000  317.00000  0.00%     -    0s
# INFO:gurobipy.gurobipy:*    0     0               0     317.0000000  317.00000  0.00%     -    0s
# INFO:root:Candidate is correct with same sign
# INFO:gurobipy.gurobipy:
# Explored 1 nodes (661 simplex iterations) in 0.27 seconds (0.16 work units)
# INFO:gurobipy.gurobipy:Explored 1 nodes (661 simplex iterations) in 0.27 seconds (0.16 work units)
# Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:
# Solution count 3: 317 27 4
# INFO:gurobipy.gurobipy:Solution count 3: 317 27 4
# INFO:gurobipy.gurobipy:
# Solve interrupted
# INFO:gurobipy.gurobipy:Solve interrupted
# Best objective 3.170000000000e+02, best bound 3.170000000000e+02, gap 0.0000%
# INFO:gurobipy.gurobipy:Best objective 3.170000000000e+02, best bound 3.170000000000e+02, gap 0.0000%
# INFO:gurobipy.gurobipy:
# User-callback calls 191, time in user-callback 0.02 sec
# INFO:gurobipy.gurobipy:User-callback calls 191, time in user-callback 0.02 sec
# DEBUG:root:Gurobi result status: "INTERRUPTED"
# INFO:root:We used 317.0 zero coefficients in y to recover the secret key.
# INFO:root:Recovery took 0.2872030735015869 seconds.
# INFO:root:Successfully recovered s_1 entry!
# INFO:root:Before filter: 1280; after filter: 300; delta: 980; threshold: 78
# INFO:root:Total filtered: 300; true: 142387; false: -142087; false-positive rate: -47362.333333333336%; probability: nan
# Set parameter Username
# INFO:gurobipy.gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2024-03-29
# INFO:gurobipy.gurobipy:Academic license - for non-commercial use only - expires 2024-03-29
# Set parameter TimeLimit to value 10
# INFO:gurobipy.gurobipy:Set parameter TimeLimit to value 10
# Set parameter Threads to value 4
# INFO:gurobipy.gurobipy:Set parameter Threads to value 4
# INFO:root:Starting recovery of an entry. Will timeout after 10s. Current datetime is: 2023-04-05 00:51:17.181218
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:
# CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# INFO:gurobipy.gurobipy:CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:
# Optimize a model with 600 rows, 556 columns and 24000 nonzeros
# INFO:gurobipy.gurobipy:Optimize a model with 600 rows, 556 columns and 24000 nonzeros
# Model fingerprint: 0x26246753
# INFO:gurobipy.gurobipy:Model fingerprint: 0x26246753
# Variable types: 0 continuous, 556 integer (300 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 556 integer (300 binary)
# Coefficient statistics:
# INFO:gurobipy.gurobipy:Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
# INFO:gurobipy.gurobipy:  Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 1e+00]
# INFO:gurobipy.gurobipy:  Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
# INFO:gurobipy.gurobipy:  Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+05, 1e+05]
# INFO:gurobipy.gurobipy:  RHS range        [1e+05, 1e+05]
# Found heuristic solution: objective 2.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 2.0000000
# Presolve time: 0.03s
# INFO:gurobipy.gurobipy:Presolve time: 0.03s
# Presolved: 600 rows, 556 columns, 24000 nonzeros
# INFO:gurobipy.gurobipy:Presolved: 600 rows, 556 columns, 24000 nonzeros
# Variable types: 0 continuous, 556 integer (300 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 556 integer (300 binary)
# Found heuristic solution: objective 24.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 24.0000000
# INFO:gurobipy.gurobipy:
# Root relaxation: objective 3.000000e+02, 788 iterations, 0.18 seconds (0.17 work units)
# INFO:gurobipy.gurobipy:Root relaxation: objective 3.000000e+02, 788 iterations, 0.18 seconds (0.17 work units)
# INFO:root:Candidate is correct with same sign
# INFO:gurobipy.gurobipy:
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy.gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy:
# *    0     0               0     300.0000000  300.00000  0.00%     -    0s
# INFO:gurobipy.gurobipy:*    0     0               0     300.0000000  300.00000  0.00%     -    0s
# INFO:root:Candidate is correct with same sign
# INFO:gurobipy.gurobipy:
# Explored 1 nodes (788 simplex iterations) in 0.35 seconds (0.20 work units)
# INFO:gurobipy.gurobipy:Explored 1 nodes (788 simplex iterations) in 0.35 seconds (0.20 work units)
# Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:
# Solution count 3: 300 24 2
# INFO:gurobipy.gurobipy:Solution count 3: 300 24 2
# INFO:gurobipy.gurobipy:
# Solve interrupted
# INFO:gurobipy.gurobipy:Solve interrupted
# Best objective 3.000000000000e+02, best bound 3.000000000000e+02, gap 0.0000%
# INFO:gurobipy.gurobipy:Best objective 3.000000000000e+02, best bound 3.000000000000e+02, gap 0.0000%
# INFO:gurobipy.gurobipy:
# User-callback calls 196, time in user-callback 0.05 sec
# INFO:gurobipy.gurobipy:User-callback calls 196, time in user-callback 0.05 sec
# DEBUG:root:Gurobi result status: "INTERRUPTED"
# INFO:root:We used 300.0 zero coefficients in y to recover the secret key.
# INFO:root:Recovery took 0.3703930377960205 seconds.
# INFO:root:Successfully recovered s_1 entry!
# INFO:root:Before filter: 1280; after filter: 316; delta: 964; threshold: 78
# INFO:root:Total filtered: 316; true: 142387; false: -142071; false-positive rate: -44959.17721518988%; probability: nan
# Set parameter Username
# INFO:gurobipy.gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2024-03-29
# INFO:gurobipy.gurobipy:Academic license - for non-commercial use only - expires 2024-03-29
# Set parameter TimeLimit to value 10
# INFO:gurobipy.gurobipy:Set parameter TimeLimit to value 10
# Set parameter Threads to value 4
# INFO:gurobipy.gurobipy:Set parameter Threads to value 4
# INFO:root:Starting recovery of an entry. Will timeout after 10s. Current datetime is: 2023-04-05 00:51:17.615153
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:
# CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# INFO:gurobipy.gurobipy:CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:
# Optimize a model with 632 rows, 572 columns and 25280 nonzeros
# INFO:gurobipy.gurobipy:Optimize a model with 632 rows, 572 columns and 25280 nonzeros
# Model fingerprint: 0x4eb5f588
# INFO:gurobipy.gurobipy:Model fingerprint: 0x4eb5f588
# Variable types: 0 continuous, 572 integer (316 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 572 integer (316 binary)
# Coefficient statistics:
# INFO:gurobipy.gurobipy:Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
# INFO:gurobipy.gurobipy:  Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 1e+00]
# INFO:gurobipy.gurobipy:  Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
# INFO:gurobipy.gurobipy:  Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+05, 1e+05]
# INFO:gurobipy.gurobipy:  RHS range        [1e+05, 1e+05]
# Found heuristic solution: objective 6.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 6.0000000
# Presolve time: 0.04s
# INFO:gurobipy.gurobipy:Presolve time: 0.04s
# Presolved: 632 rows, 572 columns, 25280 nonzeros
# INFO:gurobipy.gurobipy:Presolved: 632 rows, 572 columns, 25280 nonzeros
# Variable types: 0 continuous, 572 integer (316 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 572 integer (316 binary)
# Found heuristic solution: objective 27.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 27.0000000
# INFO:gurobipy.gurobipy:
# Root relaxation: objective 3.156869e+02, 942 iterations, 0.18 seconds (0.21 work units)
# INFO:gurobipy.gurobipy:Root relaxation: objective 3.156869e+02, 942 iterations, 0.18 seconds (0.21 work units)
# INFO:gurobipy.gurobipy:
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy.gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy:
#      0     0  315.68687    0    1   27.00000  315.68687  1069%     -    0s
# INFO:gurobipy.gurobipy:     0     0  315.68687    0    1   27.00000  315.68687  1069%     -    0s
# INFO:root:Candidate is correct with same sign
# H    0     0                     315.0000000  315.68687  0.22%     -    0s
# INFO:gurobipy.gurobipy:H    0     0                     315.0000000  315.68687  0.22%     -    0s
#      0     0  315.68687    0    1  315.00000  315.68687  0.22%     -    0s
# INFO:gurobipy.gurobipy:     0     0  315.68687    0    1  315.00000  315.68687  0.22%     -    0s
# INFO:root:Candidate is correct with same sign
# INFO:gurobipy.gurobipy:
# Explored 1 nodes (942 simplex iterations) in 0.36 seconds (0.24 work units)
# INFO:gurobipy.gurobipy:Explored 1 nodes (942 simplex iterations) in 0.36 seconds (0.24 work units)
# Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:
# Solution count 3: 315 27 6
# INFO:gurobipy.gurobipy:Solution count 3: 315 27 6
# INFO:gurobipy.gurobipy:
# Optimal solution found (tolerance 1.00e-04)
# INFO:gurobipy.gurobipy:Optimal solution found (tolerance 1.00e-04)
# Best objective 3.150000000000e+02, best bound 3.150000000000e+02, gap 0.0000%
# INFO:gurobipy.gurobipy:Best objective 3.150000000000e+02, best bound 3.150000000000e+02, gap 0.0000%
# INFO:gurobipy.gurobipy:
# User-callback calls 203, time in user-callback 0.03 sec
# INFO:gurobipy.gurobipy:User-callback calls 203, time in user-callback 0.03 sec
# DEBUG:root:Gurobi result status: "OPTIMAL"
# INFO:root:We used 315.0 zero coefficients in y to recover the secret key.
# INFO:root:Recovery took 0.3814530372619629 seconds.
# INFO:root:Successfully recovered s_1 entry!
# INFO:root:Before filter: 1280; after filter: 294; delta: 986; threshold: 78
# INFO:root:Total filtered: 294; true: 142387; false: -142093; false-positive rate: -48330.95238095238%; probability: nan
# Set parameter Username
# INFO:gurobipy.gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2024-03-29
# INFO:gurobipy.gurobipy:Academic license - for non-commercial use only - expires 2024-03-29
# Set parameter TimeLimit to value 10
# INFO:gurobipy.gurobipy:Set parameter TimeLimit to value 10
# Set parameter Threads to value 4
# INFO:gurobipy.gurobipy:Set parameter Threads to value 4
# INFO:root:Starting recovery of an entry. Will timeout after 10s. Current datetime is: 2023-04-05 00:51:18.090556
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:
# CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# INFO:gurobipy.gurobipy:CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:
# Optimize a model with 588 rows, 550 columns and 23520 nonzeros
# INFO:gurobipy.gurobipy:Optimize a model with 588 rows, 550 columns and 23520 nonzeros
# Model fingerprint: 0xa8b68b36
# INFO:gurobipy.gurobipy:Model fingerprint: 0xa8b68b36
# Variable types: 0 continuous, 550 integer (294 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 550 integer (294 binary)
# Coefficient statistics:
# INFO:gurobipy.gurobipy:Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
# INFO:gurobipy.gurobipy:  Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 1e+00]
# INFO:gurobipy.gurobipy:  Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
# INFO:gurobipy.gurobipy:  Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+05, 1e+05]
# INFO:gurobipy.gurobipy:  RHS range        [1e+05, 1e+05]
# Found heuristic solution: objective 4.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 4.0000000
# Presolve time: 0.03s
# INFO:gurobipy.gurobipy:Presolve time: 0.03s
# Presolved: 588 rows, 550 columns, 23520 nonzeros
# INFO:gurobipy.gurobipy:Presolved: 588 rows, 550 columns, 23520 nonzeros
# Variable types: 0 continuous, 550 integer (294 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 550 integer (294 binary)
# Found heuristic solution: objective 32.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 32.0000000
# INFO:gurobipy.gurobipy:
# Root relaxation: objective 2.933212e+02, 1073 iterations, 0.20 seconds (0.23 work units)
# INFO:gurobipy.gurobipy:Root relaxation: objective 2.933212e+02, 1073 iterations, 0.20 seconds (0.23 work units)
# INFO:gurobipy.gurobipy:
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy.gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy:
#      0     0  293.32116    0    3   32.00000  293.32116   817%     -    0s
# INFO:gurobipy.gurobipy:     0     0  293.32116    0    3   32.00000  293.32116   817%     -    0s
# INFO:root:Candidate is correct with same sign
# H    0     0                     291.0000000  293.32116  0.80%     -    0s
# INFO:gurobipy.gurobipy:H    0     0                     291.0000000  293.32116  0.80%     -    0s
# INFO:root:Candidate is correct with same sign
# INFO:gurobipy.gurobipy:
# Explored 1 nodes (1073 simplex iterations) in 0.40 seconds (0.26 work units)
# INFO:gurobipy.gurobipy:Explored 1 nodes (1073 simplex iterations) in 0.40 seconds (0.26 work units)
# Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:
# Solution count 3: 291 32 4
# INFO:gurobipy.gurobipy:Solution count 3: 291 32 4
# INFO:gurobipy.gurobipy:
# Solve interrupted
# INFO:gurobipy.gurobipy:Solve interrupted
# Best objective 2.910000000000e+02, best bound 2.930000000000e+02, gap 0.6873%
# INFO:gurobipy.gurobipy:Best objective 2.910000000000e+02, best bound 2.930000000000e+02, gap 0.6873%
# INFO:gurobipy.gurobipy:
# User-callback calls 209, time in user-callback 0.02 sec
# INFO:gurobipy.gurobipy:User-callback calls 209, time in user-callback 0.02 sec
# DEBUG:root:Gurobi result status: "INTERRUPTED"
# INFO:root:We used 291.0 zero coefficients in y to recover the secret key.
# INFO:root:Recovery took 0.4154689311981201 seconds.
# INFO:root:Successfully recovered s_1 entry!
# INFO:root:Before filter: 1280; after filter: 309; delta: 971; threshold: 78
# INFO:root:Total filtered: 309; true: 142387; false: -142078; false-positive rate: -45979.935275080905%; probability: nan
# Set parameter Username
# INFO:gurobipy.gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2024-03-29
# INFO:gurobipy.gurobipy:Academic license - for non-commercial use only - expires 2024-03-29
# Set parameter TimeLimit to value 10
# INFO:gurobipy.gurobipy:Set parameter TimeLimit to value 10
# Set parameter Threads to value 4
# INFO:gurobipy.gurobipy:Set parameter Threads to value 4
# INFO:root:Starting recovery of an entry. Will timeout after 10s. Current datetime is: 2023-04-05 00:51:18.582944
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:
# CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# INFO:gurobipy.gurobipy:CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:
# Optimize a model with 618 rows, 565 columns and 24720 nonzeros
# INFO:gurobipy.gurobipy:Optimize a model with 618 rows, 565 columns and 24720 nonzeros
# Model fingerprint: 0x134cc3d6
# INFO:gurobipy.gurobipy:Model fingerprint: 0x134cc3d6
# Variable types: 0 continuous, 565 integer (309 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 565 integer (309 binary)
# Coefficient statistics:
# INFO:gurobipy.gurobipy:Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
# INFO:gurobipy.gurobipy:  Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 1e+00]
# INFO:gurobipy.gurobipy:  Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
# INFO:gurobipy.gurobipy:  Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+05, 1e+05]
# INFO:gurobipy.gurobipy:  RHS range        [1e+05, 1e+05]
# Found heuristic solution: objective 8.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 8.0000000
# Presolve time: 0.04s
# INFO:gurobipy.gurobipy:Presolve time: 0.04s
# Presolved: 618 rows, 565 columns, 24720 nonzeros
# INFO:gurobipy.gurobipy:Presolved: 618 rows, 565 columns, 24720 nonzeros
# Variable types: 0 continuous, 565 integer (309 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 565 integer (309 binary)
# Found heuristic solution: objective 25.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 25.0000000
# INFO:gurobipy.gurobipy:
# Root relaxation: objective 3.084519e+02, 926 iterations, 0.19 seconds (0.20 work units)
# INFO:gurobipy.gurobipy:Root relaxation: objective 3.084519e+02, 926 iterations, 0.19 seconds (0.20 work units)
# INFO:gurobipy.gurobipy:
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy.gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy:
#      0     0  308.45192    0    2   25.00000  308.45192  1134%     -    0s
# INFO:gurobipy.gurobipy:     0     0  308.45192    0    2   25.00000  308.45192  1134%     -    0s
# INFO:root:Candidate is correct with same sign
# H    0     0                     307.0000000  308.45192  0.47%     -    0s
# INFO:gurobipy.gurobipy:H    0     0                     307.0000000  308.45192  0.47%     -    0s
# INFO:root:Candidate is correct with same sign
# INFO:gurobipy.gurobipy:
# Explored 1 nodes (926 simplex iterations) in 0.42 seconds (0.23 work units)
# INFO:gurobipy.gurobipy:Explored 1 nodes (926 simplex iterations) in 0.42 seconds (0.23 work units)
# Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:
# Solution count 3: 307 25 8
# INFO:gurobipy.gurobipy:Solution count 3: 307 25 8
# INFO:gurobipy.gurobipy:
# Solve interrupted
# INFO:gurobipy.gurobipy:Solve interrupted
# Best objective 3.070000000000e+02, best bound 3.080000000000e+02, gap 0.3257%
# INFO:gurobipy.gurobipy:Best objective 3.070000000000e+02, best bound 3.080000000000e+02, gap 0.3257%
# INFO:gurobipy.gurobipy:
# User-callback calls 204, time in user-callback 0.02 sec
# INFO:gurobipy.gurobipy:User-callback calls 204, time in user-callback 0.02 sec
# DEBUG:root:Gurobi result status: "INTERRUPTED"
# INFO:root:We used 307.0 zero coefficients in y to recover the secret key.
# INFO:root:Recovery took 0.44635701179504395 seconds.
# INFO:root:Successfully recovered s_1 entry!
# INFO:root:Before filter: 1280; after filter: 320; delta: 960; threshold: 78
# INFO:root:Total filtered: 320; true: 142387; false: -142067; false-positive rate: -44395.9375%; probability: nan
# Set parameter Username
# INFO:gurobipy.gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2024-03-29
# INFO:gurobipy.gurobipy:Academic license - for non-commercial use only - expires 2024-03-29
# Set parameter TimeLimit to value 10
# INFO:gurobipy.gurobipy:Set parameter TimeLimit to value 10
# Set parameter Threads to value 4
# INFO:gurobipy.gurobipy:Set parameter Threads to value 4
# INFO:root:Starting recovery of an entry. Will timeout after 10s. Current datetime is: 2023-04-05 00:51:19.104130
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:
# CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# INFO:gurobipy.gurobipy:CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:
# Optimize a model with 640 rows, 576 columns and 25600 nonzeros
# INFO:gurobipy.gurobipy:Optimize a model with 640 rows, 576 columns and 25600 nonzeros
# Model fingerprint: 0x6bf8654e
# INFO:gurobipy.gurobipy:Model fingerprint: 0x6bf8654e
# Variable types: 0 continuous, 576 integer (320 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 576 integer (320 binary)
# Coefficient statistics:
# INFO:gurobipy.gurobipy:Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
# INFO:gurobipy.gurobipy:  Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 1e+00]
# INFO:gurobipy.gurobipy:  Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
# INFO:gurobipy.gurobipy:  Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+05, 1e+05]
# INFO:gurobipy.gurobipy:  RHS range        [1e+05, 1e+05]
# Found heuristic solution: objective 3.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 3.0000000
# Presolve time: 0.04s
# INFO:gurobipy.gurobipy:Presolve time: 0.04s
# Presolved: 640 rows, 576 columns, 25600 nonzeros
# INFO:gurobipy.gurobipy:Presolved: 640 rows, 576 columns, 25600 nonzeros
# Variable types: 0 continuous, 576 integer (320 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 576 integer (320 binary)
# Found heuristic solution: objective 28.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 28.0000000
# INFO:gurobipy.gurobipy:
# Root relaxation: objective 3.200000e+02, 729 iterations, 0.15 seconds (0.16 work units)
# INFO:gurobipy.gurobipy:Root relaxation: objective 3.200000e+02, 729 iterations, 0.15 seconds (0.16 work units)
# INFO:root:Candidate is correct with same sign
# INFO:gurobipy.gurobipy:
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy.gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy:
# *    0     0               0     320.0000000  320.00000  0.00%     -    0s
# INFO:gurobipy.gurobipy:*    0     0               0     320.0000000  320.00000  0.00%     -    0s
# INFO:root:Candidate is correct with same sign
# INFO:gurobipy.gurobipy:
# Explored 1 nodes (729 simplex iterations) in 0.30 seconds (0.19 work units)
# INFO:gurobipy.gurobipy:Explored 1 nodes (729 simplex iterations) in 0.30 seconds (0.19 work units)
# Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:
# Solution count 3: 320 28 3
# INFO:gurobipy.gurobipy:Solution count 3: 320 28 3
# INFO:gurobipy.gurobipy:
# Solve interrupted
# INFO:gurobipy.gurobipy:Solve interrupted
# Best objective 3.200000000000e+02, best bound 3.200000000000e+02, gap 0.0000%
# INFO:gurobipy.gurobipy:Best objective 3.200000000000e+02, best bound 3.200000000000e+02, gap 0.0000%
# INFO:gurobipy.gurobipy:
# User-callback calls 195, time in user-callback 0.03 sec
# INFO:gurobipy.gurobipy:User-callback calls 195, time in user-callback 0.03 sec
# DEBUG:root:Gurobi result status: "INTERRUPTED"
# INFO:root:We used 320.0 zero coefficients in y to recover the secret key.
# INFO:root:Recovery took 0.32230305671691895 seconds.
# INFO:root:Successfully recovered s_1 entry!
# INFO:root:Before filter: 1280; after filter: 327; delta: 953; threshold: 78
# INFO:root:Total filtered: 327; true: 142387; false: -142060; false-positive rate: -43443.4250764526%; probability: nan
# Set parameter Username
# INFO:gurobipy.gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2024-03-29
# INFO:gurobipy.gurobipy:Academic license - for non-commercial use only - expires 2024-03-29
# Set parameter TimeLimit to value 10
# INFO:gurobipy.gurobipy:Set parameter TimeLimit to value 10
# Set parameter Threads to value 4
# INFO:gurobipy.gurobipy:Set parameter Threads to value 4
# INFO:root:Starting recovery of an entry. Will timeout after 10s. Current datetime is: 2023-04-05 00:51:19.516570
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:
# CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# INFO:gurobipy.gurobipy:CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:
# Optimize a model with 654 rows, 583 columns and 26160 nonzeros
# INFO:gurobipy.gurobipy:Optimize a model with 654 rows, 583 columns and 26160 nonzeros
# Model fingerprint: 0x2b0aeaa1
# INFO:gurobipy.gurobipy:Model fingerprint: 0x2b0aeaa1
# Variable types: 0 continuous, 583 integer (327 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 583 integer (327 binary)
# Coefficient statistics:
# INFO:gurobipy.gurobipy:Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
# INFO:gurobipy.gurobipy:  Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 1e+00]
# INFO:gurobipy.gurobipy:  Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
# INFO:gurobipy.gurobipy:  Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+05, 1e+05]
# INFO:gurobipy.gurobipy:  RHS range        [1e+05, 1e+05]
# Found heuristic solution: objective 13.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 13.0000000
# Presolve time: 0.05s
# INFO:gurobipy.gurobipy:Presolve time: 0.05s
# Presolved: 654 rows, 583 columns, 26160 nonzeros
# INFO:gurobipy.gurobipy:Presolved: 654 rows, 583 columns, 26160 nonzeros
# Variable types: 0 continuous, 583 integer (327 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 583 integer (327 binary)
# Found heuristic solution: objective 30.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 30.0000000
# INFO:gurobipy.gurobipy:
# Root relaxation: objective 3.265926e+02, 947 iterations, 0.18 seconds (0.21 work units)
# INFO:gurobipy.gurobipy:Root relaxation: objective 3.265926e+02, 947 iterations, 0.18 seconds (0.21 work units)
# INFO:gurobipy.gurobipy:
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy.gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy:
#      0     0  326.59259    0    1   30.00000  326.59259   989%     -    0s
# INFO:gurobipy.gurobipy:     0     0  326.59259    0    1   30.00000  326.59259   989%     -    0s
# INFO:root:Candidate is correct with same sign
# H    0     0                     326.0000000  326.59259  0.18%     -    0s
# INFO:gurobipy.gurobipy:H    0     0                     326.0000000  326.59259  0.18%     -    0s
#      0     0  326.59259    0    1  326.00000  326.59259  0.18%     -    0s
# INFO:gurobipy.gurobipy:     0     0  326.59259    0    1  326.00000  326.59259  0.18%     -    0s
# INFO:root:Candidate is correct with same sign
# INFO:gurobipy.gurobipy:
# Explored 1 nodes (947 simplex iterations) in 0.40 seconds (0.24 work units)
# INFO:gurobipy.gurobipy:Explored 1 nodes (947 simplex iterations) in 0.40 seconds (0.24 work units)
# Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:
# Solution count 3: 326 30 13
# INFO:gurobipy.gurobipy:Solution count 3: 326 30 13
# INFO:gurobipy.gurobipy:
# Optimal solution found (tolerance 1.00e-04)
# INFO:gurobipy.gurobipy:Optimal solution found (tolerance 1.00e-04)
# Best objective 3.260000000000e+02, best bound 3.260000000000e+02, gap 0.0000%
# INFO:gurobipy.gurobipy:Best objective 3.260000000000e+02, best bound 3.260000000000e+02, gap 0.0000%
# INFO:gurobipy.gurobipy:
# User-callback calls 206, time in user-callback 0.03 sec
# INFO:gurobipy.gurobipy:User-callback calls 206, time in user-callback 0.03 sec
# DEBUG:root:Gurobi result status: "OPTIMAL"
# INFO:root:We used 326.0 zero coefficients in y to recover the secret key.
# INFO:root:Recovery took 0.44586992263793945 seconds.
# INFO:root:Successfully recovered s_1 entry!
# INFO:root:Before filter: 1280; after filter: 320; delta: 960; threshold: 78
# INFO:root:Total filtered: 320; true: 142387; false: -142067; false-positive rate: -44395.9375%; probability: nan
# Set parameter Username
# INFO:gurobipy.gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2024-03-29
# INFO:gurobipy.gurobipy:Academic license - for non-commercial use only - expires 2024-03-29
# Set parameter TimeLimit to value 10
# INFO:gurobipy.gurobipy:Set parameter TimeLimit to value 10
# Set parameter Threads to value 4
# INFO:gurobipy.gurobipy:Set parameter Threads to value 4
# INFO:root:Starting recovery of an entry. Will timeout after 10s. Current datetime is: 2023-04-05 00:51:20.055749
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:
# CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# INFO:gurobipy.gurobipy:CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:
# Optimize a model with 640 rows, 576 columns and 25600 nonzeros
# INFO:gurobipy.gurobipy:Optimize a model with 640 rows, 576 columns and 25600 nonzeros
# Model fingerprint: 0x08578ad8
# INFO:gurobipy.gurobipy:Model fingerprint: 0x08578ad8
# Variable types: 0 continuous, 576 integer (320 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 576 integer (320 binary)
# Coefficient statistics:
# INFO:gurobipy.gurobipy:Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
# INFO:gurobipy.gurobipy:  Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 1e+00]
# INFO:gurobipy.gurobipy:  Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
# INFO:gurobipy.gurobipy:  Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+05, 1e+05]
# INFO:gurobipy.gurobipy:  RHS range        [1e+05, 1e+05]
# Found heuristic solution: objective 4.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 4.0000000
# Presolve time: 0.04s
# INFO:gurobipy.gurobipy:Presolve time: 0.04s
# Presolved: 640 rows, 576 columns, 25600 nonzeros
# INFO:gurobipy.gurobipy:Presolved: 640 rows, 576 columns, 25600 nonzeros
# Variable types: 0 continuous, 576 integer (320 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 576 integer (320 binary)
# Found heuristic solution: objective 24.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 24.0000000
# INFO:gurobipy.gurobipy:
# Root relaxation: objective 3.197863e+02, 1048 iterations, 0.22 seconds (0.24 work units)
# INFO:gurobipy.gurobipy:Root relaxation: objective 3.197863e+02, 1048 iterations, 0.22 seconds (0.24 work units)
# INFO:gurobipy.gurobipy:
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy.gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy:
#      0     0  319.78632    0    1   24.00000  319.78632  1232%     -    0s
# INFO:gurobipy.gurobipy:     0     0  319.78632    0    1   24.00000  319.78632  1232%     -    0s
# INFO:root:Candidate is correct with same sign
# H    0     0                     319.0000000  319.78632  0.25%     -    0s
# INFO:gurobipy.gurobipy:H    0     0                     319.0000000  319.78632  0.25%     -    0s
#      0     0  319.78632    0    1  319.00000  319.78632  0.25%     -    0s
# INFO:gurobipy.gurobipy:     0     0  319.78632    0    1  319.00000  319.78632  0.25%     -    0s
# INFO:root:Candidate is correct with same sign
# INFO:gurobipy.gurobipy:
# Explored 1 nodes (1048 simplex iterations) in 0.39 seconds (0.27 work units)
# INFO:gurobipy.gurobipy:Explored 1 nodes (1048 simplex iterations) in 0.39 seconds (0.27 work units)
# Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:
# Solution count 3: 319 24 4
# INFO:gurobipy.gurobipy:Solution count 3: 319 24 4
# INFO:gurobipy.gurobipy:
# Optimal solution found (tolerance 1.00e-04)
# INFO:gurobipy.gurobipy:Optimal solution found (tolerance 1.00e-04)
# Best objective 3.190000000000e+02, best bound 3.190000000000e+02, gap 0.0000%
# INFO:gurobipy.gurobipy:Best objective 3.190000000000e+02, best bound 3.190000000000e+02, gap 0.0000%
# INFO:gurobipy.gurobipy:
# User-callback calls 204, time in user-callback 0.01 sec
# INFO:gurobipy.gurobipy:User-callback calls 204, time in user-callback 0.01 sec
# DEBUG:root:Gurobi result status: "OPTIMAL"
# INFO:root:We used 319.0 zero coefficients in y to recover the secret key.
# INFO:root:Recovery took 0.4171760082244873 seconds.
# INFO:root:Successfully recovered s_1 entry!
# INFO:root:Before filter: 1280; after filter: 310; delta: 970; threshold: 78
# INFO:root:Total filtered: 310; true: 142387; false: -142077; false-positive rate: -45831.290322580644%; probability: nan
# Set parameter Username
# INFO:gurobipy.gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2024-03-29
# INFO:gurobipy.gurobipy:Academic license - for non-commercial use only - expires 2024-03-29
# Set parameter TimeLimit to value 10
# INFO:gurobipy.gurobipy:Set parameter TimeLimit to value 10
# Set parameter Threads to value 4
# INFO:gurobipy.gurobipy:Set parameter Threads to value 4
# INFO:root:Starting recovery of an entry. Will timeout after 10s. Current datetime is: 2023-04-05 00:51:20.542000
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:
# CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# INFO:gurobipy.gurobipy:CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:
# Optimize a model with 620 rows, 566 columns and 24800 nonzeros
# INFO:gurobipy.gurobipy:Optimize a model with 620 rows, 566 columns and 24800 nonzeros
# Model fingerprint: 0x40faffe2
# INFO:gurobipy.gurobipy:Model fingerprint: 0x40faffe2
# Variable types: 0 continuous, 566 integer (310 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 566 integer (310 binary)
# Coefficient statistics:
# INFO:gurobipy.gurobipy:Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
# INFO:gurobipy.gurobipy:  Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 1e+00]
# INFO:gurobipy.gurobipy:  Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
# INFO:gurobipy.gurobipy:  Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+05, 1e+05]
# INFO:gurobipy.gurobipy:  RHS range        [1e+05, 1e+05]
# Found heuristic solution: objective 3.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 3.0000000
# Presolve time: 0.04s
# INFO:gurobipy.gurobipy:Presolve time: 0.04s
# Presolved: 620 rows, 566 columns, 24800 nonzeros
# INFO:gurobipy.gurobipy:Presolved: 620 rows, 566 columns, 24800 nonzeros
# Variable types: 0 continuous, 566 integer (310 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 566 integer (310 binary)
# Found heuristic solution: objective 32.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 32.0000000
# INFO:gurobipy.gurobipy:
# Root relaxation: objective 3.100000e+02, 803 iterations, 0.18 seconds (0.16 work units)
# INFO:gurobipy.gurobipy:Root relaxation: objective 3.100000e+02, 803 iterations, 0.18 seconds (0.16 work units)
# INFO:root:Candidate is correct with same sign
# INFO:gurobipy.gurobipy:
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy.gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy:
# ...
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:
# Optimize a model with 680 rows, 596 columns and 27200 nonzeros
# INFO:gurobipy.gurobipy:Optimize a model with 680 rows, 596 columns and 27200 nonzeros
# Model fingerprint: 0x3fc44703
# INFO:gurobipy.gurobipy:Model fingerprint: 0x3fc44703
# Variable types: 0 continuous, 596 integer (340 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 596 integer (340 binary)
# Coefficient statistics:
# INFO:gurobipy.gurobipy:Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
# INFO:gurobipy.gurobipy:  Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 1e+00]
# INFO:gurobipy.gurobipy:  Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
# INFO:gurobipy.gurobipy:  Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+05, 1e+05]
# INFO:gurobipy.gurobipy:  RHS range        [1e+05, 1e+05]
# Found heuristic solution: objective 8.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 8.0000000
# Presolve time: 0.04s
# INFO:gurobipy.gurobipy:Presolve time: 0.04s
# Presolved: 680 rows, 596 columns, 27200 nonzeros
# INFO:gurobipy.gurobipy:Presolved: 680 rows, 596 columns, 27200 nonzeros
# Variable types: 0 continuous, 596 integer (340 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 596 integer (340 binary)
# Found heuristic solution: objective 32.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 32.0000000
# INFO:gurobipy.gurobipy:
# Root relaxation: objective 3.248839e+02, 1311 iterations, 0.37 seconds (0.31 work units)
# INFO:gurobipy.gurobipy:Root relaxation: objective 3.248839e+02, 1311 iterations, 0.37 seconds (0.31 work units)
# INFO:gurobipy.gurobipy:
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy.gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy:
#      0     0  324.88390    0   47   32.00000  324.88390   915%     -    0s
# INFO:gurobipy.gurobipy:     0     0  324.88390    0   47   32.00000  324.88390   915%     -    0s
# INFO:root:Candidate is correct with same sign
# H    0     0                     293.0000000  324.88390  10.9%     -    0s
# INFO:gurobipy.gurobipy:H    0     0                     293.0000000  324.88390  10.9%     -    0s
# INFO:root:Candidate is correct with same sign
# INFO:gurobipy.gurobipy:
# Explored 1 nodes (1311 simplex iterations) in 0.74 seconds (0.36 work units)
# INFO:gurobipy.gurobipy:Explored 1 nodes (1311 simplex iterations) in 0.74 seconds (0.36 work units)
# Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:
# Solution count 3: 293 32 8
# INFO:gurobipy.gurobipy:Solution count 3: 293 32 8
# INFO:gurobipy.gurobipy:
# Solve interrupted
# INFO:gurobipy.gurobipy:Solve interrupted
# Best objective 2.930000000000e+02, best bound 3.240000000000e+02, gap 10.5802%
# INFO:gurobipy.gurobipy:Best objective 2.930000000000e+02, best bound 3.240000000000e+02, gap 10.5802%
# INFO:gurobipy.gurobipy:
# User-callback calls 211, time in user-callback 0.04 sec
# INFO:gurobipy.gurobipy:User-callback calls 211, time in user-callback 0.04 sec
# DEBUG:root:Gurobi result status: "INTERRUPTED"
# INFO:root:We used 293.0 zero coefficients in y to recover the secret key.
# INFO:root:Recovery took 0.7763559818267822 seconds.
# INFO:root:Successfully recovered s_1 entry!
# INFO:root:Before filter: 57600; after filter: 303; delta: 57297; threshold: 78
# INFO:root:Total filtered: 303; true: 142387; false: -142084; false-positive rate: -46892.40924092409%; probability: nan
# Set parameter Username
# INFO:gurobipy.gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2024-03-29
# INFO:gurobipy.gurobipy:Academic license - for non-commercial use only - expires 2024-03-29
# Set parameter TimeLimit to value 10
# INFO:gurobipy.gurobipy:Set parameter TimeLimit to value 10
# Set parameter Threads to value 4
# INFO:gurobipy.gurobipy:Set parameter Threads to value 4
# INFO:root:Starting recovery of an entry. Will timeout after 10s. Current datetime is: 2023-04-05 00:53:37.806342
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:
# CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# INFO:gurobipy.gurobipy:CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:
# Optimize a model with 606 rows, 559 columns and 24240 nonzeros
# INFO:gurobipy.gurobipy:Optimize a model with 606 rows, 559 columns and 24240 nonzeros
# Model fingerprint: 0x95bb0367
# INFO:gurobipy.gurobipy:Model fingerprint: 0x95bb0367
# Variable types: 0 continuous, 559 integer (303 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 559 integer (303 binary)
# Coefficient statistics:
# INFO:gurobipy.gurobipy:Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
# INFO:gurobipy.gurobipy:  Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 1e+00]
# INFO:gurobipy.gurobipy:  Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
# INFO:gurobipy.gurobipy:  Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+05, 1e+05]
# INFO:gurobipy.gurobipy:  RHS range        [1e+05, 1e+05]
# Found heuristic solution: objective 7.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 7.0000000
# Presolve time: 0.03s
# INFO:gurobipy.gurobipy:Presolve time: 0.03s
# Presolved: 606 rows, 559 columns, 24240 nonzeros
# INFO:gurobipy.gurobipy:Presolved: 606 rows, 559 columns, 24240 nonzeros
# Variable types: 0 continuous, 559 integer (303 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 559 integer (303 binary)
# Found heuristic solution: objective 29.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 29.0000000
# INFO:gurobipy.gurobipy:
# Root relaxation: objective 2.913692e+02, 1515 iterations, 0.25 seconds (0.37 work units)
# INFO:gurobipy.gurobipy:Root relaxation: objective 2.913692e+02, 1515 iterations, 0.25 seconds (0.37 work units)
# INFO:gurobipy.gurobipy:
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy.gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy:
#      0     0  291.36924    0   39   29.00000  291.36924   905%     -    0s
# INFO:gurobipy.gurobipy:     0     0  291.36924    0   39   29.00000  291.36924   905%     -    0s
# INFO:root:Candidate is correct with same sign
# H    0     0                     264.0000000  291.36924  10.4%     -    0s
# INFO:gurobipy.gurobipy:H    0     0                     264.0000000  291.36924  10.4%     -    0s
# INFO:root:Candidate is correct with same sign
# INFO:gurobipy.gurobipy:
# Explored 1 nodes (1515 simplex iterations) in 0.67 seconds (0.42 work units)
# INFO:gurobipy.gurobipy:Explored 1 nodes (1515 simplex iterations) in 0.67 seconds (0.42 work units)
# Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:
# Solution count 3: 264 29 7
# INFO:gurobipy.gurobipy:Solution count 3: 264 29 7
# INFO:gurobipy.gurobipy:
# Solve interrupted
# INFO:gurobipy.gurobipy:Solve interrupted
# Best objective 2.640000000000e+02, best bound 2.910000000000e+02, gap 10.2273%
# INFO:gurobipy.gurobipy:Best objective 2.640000000000e+02, best bound 2.910000000000e+02, gap 10.2273%
# INFO:gurobipy.gurobipy:
# User-callback calls 214, time in user-callback 0.03 sec
# INFO:gurobipy.gurobipy:User-callback calls 214, time in user-callback 0.03 sec
# DEBUG:root:Gurobi result status: "INTERRUPTED"
# INFO:root:We used 264.0 zero coefficients in y to recover the secret key.
# INFO:root:Recovery took 0.7140519618988037 seconds.
# INFO:root:Successfully recovered s_1 entry!
# INFO:root:Before filter: 57600; after filter: 310; delta: 57290; threshold: 78
# INFO:root:Total filtered: 310; true: 142387; false: -142077; false-positive rate: -45831.290322580644%; probability: nan
# Set parameter Username
# INFO:gurobipy.gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2024-03-29
# INFO:gurobipy.gurobipy:Academic license - for non-commercial use only - expires 2024-03-29
# Set parameter TimeLimit to value 10
# INFO:gurobipy.gurobipy:Set parameter TimeLimit to value 10
# Set parameter Threads to value 4
# INFO:gurobipy.gurobipy:Set parameter Threads to value 4
# INFO:root:Starting recovery of an entry. Will timeout after 10s. Current datetime is: 2023-04-05 00:53:38.662730
# Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:Gurobi Optimizer version 10.0.1 build v10.0.1rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:
# CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# INFO:gurobipy.gurobipy:CPU model: Intel(R) Core(TM) i5-7267U CPU @ 3.10GHz
# Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:Thread count: 2 physical cores, 4 logical processors, using up to 4 threads
# INFO:gurobipy.gurobipy:
# Optimize a model with 620 rows, 566 columns and 24800 nonzeros
# INFO:gurobipy.gurobipy:Optimize a model with 620 rows, 566 columns and 24800 nonzeros
# Model fingerprint: 0x6e8e224f
# INFO:gurobipy.gurobipy:Model fingerprint: 0x6e8e224f
# Variable types: 0 continuous, 566 integer (310 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 566 integer (310 binary)
# Coefficient statistics:
# INFO:gurobipy.gurobipy:Coefficient statistics:
#   Matrix range     [1e+00, 1e+05]
# INFO:gurobipy.gurobipy:  Matrix range     [1e+00, 1e+05]
#   Objective range  [1e+00, 1e+00]
# INFO:gurobipy.gurobipy:  Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 2e+00]
# INFO:gurobipy.gurobipy:  Bounds range     [1e+00, 2e+00]
#   RHS range        [1e+05, 1e+05]
# INFO:gurobipy.gurobipy:  RHS range        [1e+05, 1e+05]
# Found heuristic solution: objective 8.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 8.0000000
# Presolve removed 1 rows and 0 columns
# INFO:gurobipy.gurobipy:Presolve removed 1 rows and 0 columns
# Presolve time: 0.03s
# INFO:gurobipy.gurobipy:Presolve time: 0.03s
# Presolved: 619 rows, 566 columns, 24760 nonzeros
# INFO:gurobipy.gurobipy:Presolved: 619 rows, 566 columns, 24760 nonzeros
# Variable types: 0 continuous, 566 integer (310 binary)
# INFO:gurobipy.gurobipy:Variable types: 0 continuous, 566 integer (310 binary)
# Found heuristic solution: objective 31.0000000
# INFO:gurobipy.gurobipy:Found heuristic solution: objective 31.0000000
# INFO:gurobipy.gurobipy:
# Root relaxation: objective 2.988943e+02, 1606 iterations, 0.30 seconds (0.39 work units)
# INFO:gurobipy.gurobipy:Root relaxation: objective 2.988943e+02, 1606 iterations, 0.30 seconds (0.39 work units)
# INFO:gurobipy.gurobipy:
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy.gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy:
#      0     0  298.89433    0   37   31.00000  298.89433   864%     -    0s
# INFO:gurobipy.gurobipy:     0     0  298.89433    0   37   31.00000  298.89433   864%     -    0s
# INFO:root:Candidate is correct with same sign
# H    0     0                     273.0000000  298.89433  9.49%     -    0s
# INFO:gurobipy.gurobipy:H    0     0                     273.0000000  298.89433  9.49%     -    0s
# INFO:root:Candidate is correct with same sign
# INFO:gurobipy.gurobipy:
# Explored 1 nodes (1606 simplex iterations) in 0.59 seconds (0.44 work units)
# INFO:gurobipy.gurobipy:Explored 1 nodes (1606 simplex iterations) in 0.59 seconds (0.44 work units)
# Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:Thread count was 4 (of 4 available processors)
# INFO:gurobipy.gurobipy:
# Solution count 3: 273 31 8
# INFO:gurobipy.gurobipy:Solution count 3: 273 31 8
# INFO:gurobipy.gurobipy:
# Solve interrupted
# INFO:gurobipy.gurobipy:Solve interrupted
# Best objective 2.730000000000e+02, best bound 2.980000000000e+02, gap 9.1575%
# INFO:gurobipy.gurobipy:Best objective 2.730000000000e+02, best bound 2.980000000000e+02, gap 9.1575%
# INFO:gurobipy.gurobipy:
# User-callback calls 219, time in user-callback 0.03 sec
# INFO:gurobipy.gurobipy:User-callback calls 219, time in user-callback 0.03 sec
# DEBUG:root:Gurobi result status: "INTERRUPTED"
# INFO:root:We used 273.0 zero coefficients in y to recover the secret key.
# INFO:root:Recovery took 0.6068110466003418 seconds.
# INFO:root:Successfully recovered s_1 entry!
# Done trying to recover!
#                          abs_z_le_beta_vc                      time
# poly_index
# 0                        {253: 4, 254: 1} 0 days 00:00:42.038979053  \
# 1                {249: 3, 251: 1, 252: 1} 0 days 00:00:46.006530046
# 2                {246: 2, 245: 2, 247: 1} 0 days 00:01:01.733885288
# 3                        {241: 4, 242: 1} 0 days 00:00:38.796548367
# 4                        {237: 4, 238: 1} 0 days 00:01:00.558928728
# ...                                   ...                       ...
# 58          {21: 32, 22: 22, 23: 5, 20... 0 days 00:14:01.127526759
# 59          {17: 40, 18: 22, 19: 8, 16... 0 days 00:22:17.794250965
# 60          {13: 54, 14: 34, 15: 7, 12... 0 days 00:26:33.382155895
# 61          {9: 63, 10: 43, 11: 16, 12... 0 days 00:30:31.847288609
# 62          {5: 116, 6: 74, 7: 23, 8: ... 0 days 00:48:38.609140158
#
#                                    packed  success_rate  num_good  num_bad
# poly_index
# 0           {b'\xeb~\xf3\xb3\xd3&\x9e\...      0.094340         5       48  \
# 1           {b'<\x1f.\x80\xd0\x12\xa7\...      0.089286         5       51
# 2           {b'\x1d\x10\xb8\xf80\x03\x...      0.065789         5       71
# 3           {b'\x1f\xc2\x8a\xadin[\x12...      0.104167         5       43
# 4           {b'\x7f\xe0.n\xed\xe3[]=\x...      0.066667         5       70
# ...                                   ...           ...       ...      ...
# 58          {b'pN\xcb\xa8\xc7\x82\xcf\...      0.058485        61      982
# 59          {b'\x9eM\x84\xa4[\x1cu\x89...      0.044405        75     1614
# 60          {b'7\xf8\xd7\x9b*\xaa\x1am...      0.050370       102     1923
# 61          {b'\x02=\x0f\x8e\xc7\x80\x...      0.056848       132     2190
# 62          {b'\xe5IH\xcd!\xa7\xb5V\xf...      0.060959       225     3466
#
#             num_distinct_sigs                         result
# poly_index
# 0                           5  [([0.0, 1.0, 2.0, -2.0, -1...
# 1                           5  [([0.0, 1.0, 2.0, -2.0, -1...
# 2                           5  [([0.0, 1.0, 2.0, -2.0, -1...
# 3                           5  [([0.0, 1.0, 2.0, -2.0, -1...
# 4                           5  [([0.0, 1.0, 2.0, -2.0, -1...
# ...                       ...                            ...
# 58                         61  [([0.0, 1.0, 2.0, -2.0, -1...
# 59                         75  [([0.0, 1.0, 2.0, -2.0, -1...
# 60                        102  [([0.0, 1.0, 2.0, -2.0, -1...
# 61                        132  [([0.0, 1.0, 2.0, -2.0, -1...
# 62                        225  [([0.0, 1.0, 2.0, -2.0, -1...
#
# [63 rows x 8 columns]

# %%
df_grouped  # display here because gurobi spams stdout of cell above
# Out:
#                          abs_z_le_beta_vc                      time
# poly_index
# 0                        {253: 4, 254: 1} 0 days 00:00:42.038979053  \
# 1                {249: 3, 251: 1, 252: 1} 0 days 00:00:46.006530046
# 2                {246: 2, 245: 2, 247: 1} 0 days 00:01:01.733885288
# 3                        {241: 4, 242: 1} 0 days 00:00:38.796548367
# 4                        {237: 4, 238: 1} 0 days 00:01:00.558928728
# ...                                   ...                       ...
# 58          {21: 32, 22: 22, 23: 5, 20... 0 days 00:14:01.127526759
# 59          {17: 40, 18: 22, 19: 8, 16... 0 days 00:22:17.794250965
# 60          {13: 54, 14: 34, 15: 7, 12... 0 days 00:26:33.382155895
# 61          {9: 63, 10: 43, 11: 16, 12... 0 days 00:30:31.847288609
# 62          {5: 116, 6: 74, 7: 23, 8: ... 0 days 00:48:38.609140158
#
#                                    packed  success_rate  num_good  num_bad
# poly_index
# 0           {b'\xeb~\xf3\xb3\xd3&\x9e\...      0.094340         5       48  \
# 1           {b'<\x1f.\x80\xd0\x12\xa7\...      0.089286         5       51
# 2           {b'\x1d\x10\xb8\xf80\x03\x...      0.065789         5       71
# 3           {b'\x1f\xc2\x8a\xadin[\x12...      0.104167         5       43
# 4           {b'\x7f\xe0.n\xed\xe3[]=\x...      0.066667         5       70
# ...                                   ...           ...       ...      ...
# 58          {b'pN\xcb\xa8\xc7\x82\xcf\...      0.058485        61      982
# 59          {b'\x9eM\x84\xa4[\x1cu\x89...      0.044405        75     1614
# 60          {b'7\xf8\xd7\x9b*\xaa\x1am...      0.050370       102     1923
# 61          {b'\x02=\x0f\x8e\xc7\x80\x...      0.056848       132     2190
# 62          {b'\xe5IH\xcd!\xa7\xb5V\xf...      0.060959       225     3466
#
#             num_distinct_sigs                         result
# poly_index
# 0                           5  [([0.0, 1.0, 2.0, -2.0, -1...
# 1                           5  [([0.0, 1.0, 2.0, -2.0, -1...
# 2                           5  [([0.0, 1.0, 2.0, -2.0, -1...
# 3                           5  [([0.0, 1.0, 2.0, -2.0, -1...
# 4                           5  [([0.0, 1.0, 2.0, -2.0, -1...
# ...                       ...                            ...
# 58                         61  [([0.0, 1.0, 2.0, -2.0, -1...
# 59                         75  [([0.0, 1.0, 2.0, -2.0, -1...
# 60                        102  [([0.0, 1.0, 2.0, -2.0, -1...
# 61                        132  [([0.0, 1.0, 2.0, -2.0, -1...
# 62                        225  [([0.0, 1.0, 2.0, -2.0, -1...
#
# [63 rows x 8 columns]

# %%
df_grouped_boom = df_grouped.copy()

df_grouped_boom['result'] = df_grouped_boom['result'].apply(lambda result: list(enumerate(result)))
df_grouped_boom = df_grouped_boom.explode('result')

df_grouped_boom['s1_index'] = df_grouped_boom['result'].apply(lambda result_tuple: result_tuple[0])
df_grouped_boom['recovered_s1_poly'] = df_grouped_boom['result'].apply(lambda result_tuple: result_tuple[1][0].astype(np.int64))
df_grouped_boom['result_only'] = df_grouped_boom['result'].apply(lambda result_tuple: result_tuple[1][1])
del df_grouped_boom['result']

for resultKey in df_grouped_boom.iloc[0]['result_only'].keys():
    df_grouped_boom[resultKey.value] = df_grouped_boom['result_only'].apply(lambda result: result[resultKey])
del df_grouped_boom['result_only']
df_grouped_boom['duration'] = pd.to_timedelta(df_grouped_boom['duration'], unit='s')

df_grouped_boom = df_grouped_boom.rename(columns={'time': 'time_collect', 'duration': 'time_ilp'})
df_grouped_boom['time_total'] = df_grouped_boom['time_collect'] + df_grouped_boom['time_ilp']

df_grouped_boom.set_index('s1_index', append=True, inplace=True)


#df_grouped_boom = pd.concat([df_grouped_boom, pd.DataFrame(df_grouped_boom['result_only'].tolist())], axis=1)


df_grouped_boom
# Out:
#                                   abs_z_le_beta_vc              time_collect
# poly_index s1_index
# 0          0                      {253: 4, 254: 1} 0 days 00:00:42.038979053  \
#            1                      {253: 4, 254: 1} 0 days 00:00:42.038979053
#            2                      {253: 4, 254: 1} 0 days 00:00:42.038979053
#            3                      {253: 4, 254: 1} 0 days 00:00:42.038979053
# 1          0              {249: 3, 251: 1, 252: 1} 0 days 00:00:46.006530046
# ...                                            ...                       ...
# 61         3         {9: 63, 10: 43, 11: 16, 12... 0 days 00:30:31.847288609
# 62         0         {5: 116, 6: 74, 7: 23, 8: ... 0 days 00:48:38.609140158
#            1         {5: 116, 6: 74, 7: 23, 8: ... 0 days 00:48:38.609140158
#            2         {5: 116, 6: 74, 7: 23, 8: ... 0 days 00:48:38.609140158
#            3         {5: 116, 6: 74, 7: 23, 8: ... 0 days 00:48:38.609140158
#
#                                             packed  success_rate  num_good
# poly_index s1_index
# 0          0         {b'\xeb~\xf3\xb3\xd3&\x9e\...      0.094340         5  \
#            1         {b'\xeb~\xf3\xb3\xd3&\x9e\...      0.094340         5
#            2         {b'\xeb~\xf3\xb3\xd3&\x9e\...      0.094340         5
#            3         {b'\xeb~\xf3\xb3\xd3&\x9e\...      0.094340         5
# 1          0         {b'<\x1f.\x80\xd0\x12\xa7\...      0.089286         5
# ...                                            ...           ...       ...
# 61         3         {b'\x02=\x0f\x8e\xc7\x80\x...      0.056848       132
# 62         0         {b'\xe5IH\xcd!\xa7\xb5V\xf...      0.060959       225
#            1         {b'\xe5IH\xcd!\xa7\xb5V\xf...      0.060959       225
#            2         {b'\xe5IH\xcd!\xa7\xb5V\xf...      0.060959       225
#            3         {b'\xe5IH\xcd!\xa7\xb5V\xf...      0.060959       225
#
#                      num_bad  num_distinct_sigs
# poly_index s1_index
# 0          0              48                  5  \
#            1              48                  5
#            2              48                  5
#            3              48                  5
# 1          0              51                  5
# ...                      ...                ...
# 61         3            2190                132
# 62         0            3466                225
#            1            3466                225
#            2            3466                225
#            3            3466                225
#
#                                  recovered_s1_poly  faulted_coeffs
# poly_index s1_index
# 0          0         [0, 1, 2, -2, -1, -1, -2, ...          142387  \
#            1         [1, 0, -1, 1, 1, -1, 0, 2,...          142387
#            2         [-2, 0, 1, 1, -1, -2, 0, -...          142387
#            3         [0, -1, -1, 0, 0, -1, 2, 2...          142387
# 1          0         [0, 1, 2, -2, -1, -1, -2, ...          142387
# ...                                            ...             ...
# 61         3         [0, -1, -1, 0, 0, -1, 2, 2...          142387
# 62         0         [0, 1, 2, -2, -1, -1, -2, ...          142387
#            1         [1, 0, -1, 1, 1, -1, 0, 2,...          142387
#            2         [-2, 0, 1, 1, -1, -2, 0, -...          142387
#            3         [0, -1, -1, 0, 0, -1, 2, 2...          142387
#
#                      total_equations  filtered_equations
# poly_index s1_index
# 0          0                    1280                 333  \
#            1                    1280                 317
#            2                    1280                 300
#            3                    1280                 316
# 1          0                    1280                 294
# ...                              ...                 ...
# 61         3                   33792                 310
# 62         0                   57600                 316
#            1                   57600                 340
#            2                   57600                 303
#            3                   57600                 310
#
#                                      time_ilp  failure  equations_used
# poly_index s1_index
# 0          0           0 days 00:00:00.312711    False           333.0  \
#            1        0 days 00:00:00.287203074    False           317.0
#            2        0 days 00:00:00.370393038    False           300.0
#            3        0 days 00:00:00.381453037    False           315.0
# 1          0        0 days 00:00:00.415468931    False           291.0
# ...                                       ...      ...             ...
# 61         3        0 days 00:00:00.514958857    False           282.0
# 62         0        0 days 00:00:00.479923964    False           288.0
#            1        0 days 00:00:00.776355982    False           293.0
#            2        0 days 00:00:00.714051962    False           264.0
#            3        0 days 00:00:00.606811047    False           273.0
#
#                                    time_total
# poly_index s1_index
# 0          0        0 days 00:00:42.351690053
#            1        0 days 00:00:42.326182127
#            2        0 days 00:00:42.409372091
#            3        0 days 00:00:42.420432090
# 1          0        0 days 00:00:46.421998977
# ...                                       ...
# 61         3        0 days 00:30:32.362247466
# 62         0        0 days 00:48:39.089064122
#            1        0 days 00:48:39.385496140
#            2        0 days 00:48:39.323192120
#            3        0 days 00:48:39.215951205
#
# [252 rows x 15 columns]

# %%
df_regrouped = df_grouped_boom.groupby(level='poly_index').agg({
    'time_total': sum,
    'time_ilp': sum,
    'time_collect': sum,
    'failure': any,
    'num_distinct_sigs': lambda series: series.iloc[0],
    'success_rate': lambda series: series.iloc[0],
    'abs_z_le_beta_vc': lambda series: sum([val * freq for val, freq in series.iloc[0].items()]),
})
df_regrouped = df_regrouped.rename(columns={'abs_z_le_beta_vc': 'total_zero_coeffs_approx (upper_bound)'})
correction_factor = 4.25  # see Table 2: Parameters of Dilithium in dilithium_nist.pdf
df_regrouped['success_rate_fault'] = df_regrouped['success_rate'] * correction_factor  # are these events fully independent? i think so ...

df_regrouped
# Out:
#                           time_total                  time_ilp
# poly_index
# 0          0 days 00:02:49.507676361 0 days 00:00:01.351760149  \
# 1          0 days 00:03:05.656119107 0 days 00:00:01.629998923
# 2          0 days 00:04:08.544657230 0 days 00:00:01.609116078
# 3          0 days 00:02:36.828431847 0 days 00:00:01.642238379
# 4          0 days 00:04:04.150524854 0 days 00:00:01.914809942
# ...                              ...                       ...
# 58         0 days 00:56:06.227320905 0 days 00:00:01.717213869
# 59         0 days 01:29:12.972656726 0 days 00:00:01.795652866
# 60         0 days 01:46:15.552562712 0 days 00:00:02.023939132
# 61         0 days 02:02:09.718218088 0 days 00:00:02.329063652
# 62         0 days 03:14:37.013703587 0 days 00:00:02.577142955
#
#                         time_collect  failure  num_distinct_sigs
# poly_index
# 0          0 days 00:02:48.155916212    False                  5  \
# 1          0 days 00:03:04.026120184    False                  5
# 2          0 days 00:04:06.935541152    False                  5
# 3          0 days 00:02:35.186193468    False                  5
# 4          0 days 00:04:02.235714912    False                  5
# ...                              ...      ...                ...
# 58         0 days 00:56:04.510107036    False                 61
# 59         0 days 01:29:11.177003860    False                 75
# 60         0 days 01:46:13.528623580    False                102
# 61         0 days 02:02:07.389154436    False                132
# 62         0 days 03:14:34.436560632    False                225
#
#             success_rate  total_zero_coeffs_approx (upper_bound)
# poly_index
# 0               0.094340                           1266           \
# 1               0.089286                           1250
# 2               0.065789                           1229
# 3               0.104167                           1206
# 4               0.066667                           1186
# ...                  ...                            ...
# 58              0.058485                           1315
# 59              0.044405                           1312
# 60              0.050370                           1375
# 61              0.056848                           1286
# 62              0.060959                           1269
#
#             success_rate_fault
# poly_index
# 0                     0.400943
# 1                     0.379464
# 2                     0.279605
# 3                     0.442708
# 4                     0.283333
# ...                        ...
# 58                    0.248562
# 59                    0.188721
# 60                    0.214074
# 61                    0.241602
# 62                    0.259076
#
# [63 rows x 8 columns]

# %%
df_print = pd.concat([df_regrouped.add_prefix('rg.'), df_grouped.add_prefix('g.')], axis=1)
#df_print = df_print[['time_total', 'time_ilp', 'time_collect', 'failure' num_distinct_sigs 	success_rate 	total_zero_coeffs_approx (upper_bound) 	success_rate_fault]]
df_print = df_print[[
    'rg.time_total',
    'rg.time_ilp',
    'rg.time_collect',
    'rg.failure',
    'rg.num_distinct_sigs',
    'rg.success_rate',
    'rg.total_zero_coeffs_approx (upper_bound)',
    'rg.success_rate_fault',
    # the new ones ...
    'g.num_good',
    'g.num_bad'
]]
df_print['g.total'] = df_print['g.num_good'] + df_print['g.num_bad']
# remove prefixes as we know no dupes
df_print = df_print.rename(columns=lambda x: x.split('.')[1])
# for latex
df_print['min_zeroed_coeffs'] = df_print.reset_index()['poly_index'].apply(lambda idx: (63 - idx) * 4)

display(df_print)
print(df_print.to_markdown())
# Out:
#                           time_total                  time_ilp
# poly_index
# 0          0 days 00:02:49.507676361 0 days 00:00:01.351760149  \
# 1          0 days 00:03:05.656119107 0 days 00:00:01.629998923
# 2          0 days 00:04:08.544657230 0 days 00:00:01.609116078
# 3          0 days 00:02:36.828431847 0 days 00:00:01.642238379
# 4          0 days 00:04:04.150524854 0 days 00:00:01.914809942
# ...                              ...                       ...
# 58         0 days 00:56:06.227320905 0 days 00:00:01.717213869
# 59         0 days 01:29:12.972656726 0 days 00:00:01.795652866
# 60         0 days 01:46:15.552562712 0 days 00:00:02.023939132
# 61         0 days 02:02:09.718218088 0 days 00:00:02.329063652
# 62         0 days 03:14:37.013703587 0 days 00:00:02.577142955
#
#                         time_collect  failure  num_distinct_sigs
# poly_index
# 0          0 days 00:02:48.155916212    False                  5  \
# 1          0 days 00:03:04.026120184    False                  5
# 2          0 days 00:04:06.935541152    False                  5
# 3          0 days 00:02:35.186193468    False                  5
# 4          0 days 00:04:02.235714912    False                  5
# ...                              ...      ...                ...
# 58         0 days 00:56:04.510107036    False                 61
# 59         0 days 01:29:11.177003860    False                 75
# 60         0 days 01:46:13.528623580    False                102
# 61         0 days 02:02:07.389154436    False                132
# 62         0 days 03:14:34.436560632    False                225
#
#             success_rate  total_zero_coeffs_approx (upper_bound)
# poly_index
# 0               0.094340                           1266           \
# 1               0.089286                           1250
# 2               0.065789                           1229
# 3               0.104167                           1206
# 4               0.066667                           1186
# ...                  ...                            ...
# 58              0.058485                           1315
# 59              0.044405                           1312
# 60              0.050370                           1375
# 61              0.056848                           1286
# 62              0.060959                           1269
#
#             success_rate_fault  num_good  num_bad  total  min_zeroed_coeffs
# poly_index
# 0                     0.400943         5       48     53                252
# 1                     0.379464         5       51     56                248
# 2                     0.279605         5       71     76                244
# 3                     0.442708         5       43     48                240
# 4                     0.283333         5       70     75                236
# ...                        ...       ...      ...    ...                ...
# 58                    0.248562        61      982   1043                 20
# 59                    0.188721        75     1614   1689                 16
# 60                    0.214074       102     1923   2025                 12
# 61                    0.241602       132     2190   2322                  8
# 62                    0.259076       225     3466   3691                  4
#
# [63 rows x 12 columns]
# |   poly_index | time_total                | time_ilp                  | time_collect              | failure   |   num_distinct_sigs |   success_rate |   total_zero_coeffs_approx (upper_bound) |   success_rate_fault |   num_good |   num_bad |   total |   min_zeroed_coeffs |
# |-------------:|:--------------------------|:--------------------------|:--------------------------|:----------|--------------------:|---------------:|-----------------------------------------:|---------------------:|-----------:|----------:|--------:|--------------------:|
# |            0 | 0 days 00:02:49.507676361 | 0 days 00:00:01.351760149 | 0 days 00:02:48.155916212 | False     |                   5 |      0.0943396 |                                     1266 |             0.400943 |          5 |        48 |      53 |                 252 |
# |            1 | 0 days 00:03:05.656119107 | 0 days 00:00:01.629998923 | 0 days 00:03:04.026120184 | False     |                   5 |      0.0892857 |                                     1250 |             0.379464 |          5 |        51 |      56 |                 248 |
# |            2 | 0 days 00:04:08.544657230 | 0 days 00:00:01.609116078 | 0 days 00:04:06.935541152 | False     |                   5 |      0.0657895 |                                     1229 |             0.279605 |          5 |        71 |      76 |                 244 |
# |            3 | 0 days 00:02:36.828431847 | 0 days 00:00:01.642238379 | 0 days 00:02:35.186193468 | False     |                   5 |      0.104167  |                                     1206 |             0.442708 |          5 |        43 |      48 |                 240 |
# |            4 | 0 days 00:04:04.150524854 | 0 days 00:00:01.914809942 | 0 days 00:04:02.235714912 | False     |                   5 |      0.0666667 |                                     1186 |             0.283333 |          5 |        70 |      75 |                 236 |
# |            5 | 0 days 00:03:50.535307645 | 0 days 00:00:01.714713813 | 0 days 00:03:48.820593832 | False     |                   6 |      0.0857143 |                                     1401 |             0.364286 |          6 |        64 |      70 |                 232 |
# |            6 | 0 days 00:09:17.837238072 | 0 days 00:00:01.998453856 | 0 days 00:09:15.838784216 | False     |                   6 |      0.0324324 |                                     1378 |             0.137838 |          6 |       179 |     185 |                 228 |
# |            7 | 0 days 00:05:07.501881358 | 0 days 00:00:02.266134022 | 0 days 00:05:05.235747336 | False     |                   6 |      0.0625    |                                     1351 |             0.265625 |          6 |        90 |      96 |                 224 |
# |            8 | 0 days 00:04:07.422921421 | 0 days 00:00:01.964349985 | 0 days 00:04:05.458571436 | False     |                   6 |      0.0779221 |                                     1333 |             0.331169 |          6 |        71 |      77 |                 220 |
# |            9 | 0 days 00:05:49.382239102 | 0 days 00:00:01.940773726 | 0 days 00:05:47.441465376 | False     |                   6 |      0.0550459 |                                     1302 |             0.233945 |          6 |       103 |     109 |                 216 |
# |           10 | 0 days 00:02:36.931784868 | 0 days 00:00:01.695056200 | 0 days 00:02:35.236728668 | False     |                   6 |      0.125     |                                     1281 |             0.53125  |          6 |        42 |      48 |                 212 |
# |           11 | 0 days 00:06:05.852716445 | 0 days 00:00:01.717245101 | 0 days 00:06:04.135471344 | False     |                   6 |      0.0526316 |                                     1255 |             0.223684 |          6 |       108 |     114 |                 208 |
# |           12 | 0 days 00:07:28.038728477 | 0 days 00:00:01.616443397 | 0 days 00:07:26.422285080 | False     |                   6 |      0.0413793 |                                     1232 |             0.175862 |          6 |       139 |     145 |                 204 |
# |           13 | 0 days 00:02:17.784459828 | 0 days 00:00:01.504548788 | 0 days 00:02:16.279911040 | False     |                   6 |      0.146341  |                                     1207 |             0.621951 |          6 |        35 |      41 |                 200 |
# |           14 | 0 days 00:03:19.486236571 | 0 days 00:00:02.074729919 | 0 days 00:03:17.411506652 | False     |                   7 |      0.116667  |                                     1384 |             0.495833 |          7 |        53 |      60 |                 196 |
# |           15 | 0 days 00:09:27.329976560 | 0 days 00:00:01.734013080 | 0 days 00:09:25.595963480 | False     |                   7 |      0.0376344 |                                     1355 |             0.159946 |          7 |       179 |     186 |                 192 |
# |           16 | 0 days 00:05:44.911015749 | 0 days 00:00:01.605778933 | 0 days 00:05:43.305236816 | False     |                   7 |      0.0648148 |                                     1325 |             0.275463 |          7 |       101 |     108 |                 188 |
# |           17 | 0 days 00:07:01.724806545 | 0 days 00:00:01.802035093 | 0 days 00:06:59.922771452 | False     |                   7 |      0.0522388 |                                     1298 |             0.222015 |          7 |       127 |     134 |                 184 |
# |           18 | 0 days 00:05:58.099223612 | 0 days 00:00:01.569237232 | 0 days 00:05:56.529986380 | False     |                   7 |      0.0614035 |                                     1270 |             0.260965 |          7 |       107 |     114 |                 180 |
# |           19 | 0 days 00:03:51.099556684 | 0 days 00:00:01.759159804 | 0 days 00:03:49.340396880 | False     |                   7 |      0.0985915 |                                     1248 |             0.419014 |          7 |        64 |      71 |                 176 |
# |           20 | 0 days 00:04:12.770132780 | 0 days 00:00:01.588970900 | 0 days 00:04:11.181161880 | False     |                   7 |      0.0897436 |                                     1215 |             0.38141  |          7 |        71 |      78 |                 172 |
# |           21 | 0 days 00:06:01.507348776 | 0 days 00:00:01.669524908 | 0 days 00:05:59.837823868 | False     |                   7 |      0.0598291 |                                     1188 |             0.254274 |          7 |       110 |     117 |                 168 |
# |           22 | 0 days 00:07:51.429630040 | 0 days 00:00:01.969117880 | 0 days 00:07:49.460512160 | False     |                   8 |      0.0526316 |                                     1324 |             0.223684 |          8 |       144 |     152 |                 164 |
# |           23 | 0 days 00:08:43.406643152 | 0 days 00:00:01.752598048 | 0 days 00:08:41.654045104 | False     |                   8 |      0.0473373 |                                     1290 |             0.201183 |          8 |       161 |     169 |                 160 |
# |           24 | 0 days 00:14:14.436759949 | 0 days 00:00:01.823837281 | 0 days 00:14:12.612922668 | False     |                   8 |      0.0289855 |                                     1263 |             0.123188 |          8 |       268 |     276 |                 156 |
# |           25 | 0 days 00:07:19.807690620 | 0 days 00:00:01.783536912 | 0 days 00:07:18.024153708 | False     |                   9 |      0.0647482 |                                     1382 |             0.27518  |          9 |       130 |     139 |                 152 |
# |           26 | 0 days 00:05:29.132738350 | 0 days 00:00:02.014823198 | 0 days 00:05:27.117915152 | False     |                   9 |      0.0882353 |                                     1343 |             0.375    |          9 |        93 |     102 |                 148 |
# |           27 | 0 days 00:07:01.561465023 | 0 days 00:00:02.741144895 | 0 days 00:06:58.820320128 | False     |                   9 |      0.0681818 |                                     1310 |             0.289773 |          9 |       123 |     132 |                 144 |
# |           28 | 0 days 00:06:10.647192956 | 0 days 00:00:02.958700180 | 0 days 00:06:07.688492776 | False     |                   9 |      0.0789474 |                                     1271 |             0.335526 |          9 |       105 |     114 |                 140 |
# |           29 | 0 days 00:05:54.206138371 | 0 days 00:00:03.477476835 | 0 days 00:05:50.728661536 | False     |                   9 |      0.0810811 |                                     1235 |             0.344595 |          9 |       102 |     111 |                 136 |
# |           30 | 0 days 00:05:52.759034871 | 0 days 00:00:02.678765059 | 0 days 00:05:50.080269812 | False     |                  10 |      0.0934579 |                                     1337 |             0.397196 |         10 |        97 |     107 |                 132 |
# |           31 | 0 days 00:05:10.536821365 | 0 days 00:00:02.936443329 | 0 days 00:05:07.600378036 | False     |                  10 |      0.104167  |                                     1295 |             0.442708 |         10 |        86 |      96 |                 128 |
# |           32 | 0 days 00:06:02.982755661 | 0 days 00:00:02.438570977 | 0 days 00:06:00.544184684 | False     |                  10 |      0.0884956 |                                     1250 |             0.376106 |         10 |       103 |     113 |                 124 |
# |           33 | 0 days 00:06:50.876749276 | 0 days 00:00:01.892730952 | 0 days 00:06:48.984018324 | False     |                  10 |      0.078125  |                                     1218 |             0.332031 |         10 |       118 |     128 |                 120 |
# |           34 | 0 days 00:13:44.365277768 | 0 days 00:00:01.243607044 | 0 days 00:13:43.121670724 | False     |                  10 |      0.03663   |                                     1171 |             0.155678 |         10 |       263 |     273 |                 116 |
# |           35 | 0 days 00:08:03.235713960 | 0 days 00:00:01.514417648 | 0 days 00:08:01.721296312 | False     |                  11 |      0.0743243 |                                     1250 |             0.315878 |         11 |       137 |     148 |                 112 |
# |           36 | 0 days 00:11:05.098385809 | 0 days 00:00:01.709345817 | 0 days 00:11:03.389039992 | False     |                  12 |      0.0566038 |                                     1313 |             0.240566 |         12 |       200 |     212 |                 108 |
# |           37 | 0 days 00:13:46.102480889 | 0 days 00:00:01.859334945 | 0 days 00:13:44.243145944 | False     |                  12 |      0.0458015 |                                     1265 |             0.194656 |         12 |       250 |     262 |                 104 |
# |           38 | 0 days 00:13:15.634337901 | 0 days 00:00:01.974685193 | 0 days 00:13:13.659652708 | False     |                  13 |      0.0505837 |                                     1316 |             0.214981 |         13 |       244 |     257 |                 100 |
# |           39 | 0 days 00:12:19.081026316 | 0 days 00:00:01.956980944 | 0 days 00:12:17.124045372 | False     |                  14 |      0.0598291 |                                     1366 |             0.254274 |         14 |       220 |     234 |                  96 |
# |           40 | 0 days 00:19:41.220188856 | 0 days 00:00:01.754355192 | 0 days 00:19:39.465833664 | False     |                  14 |      0.0362694 |                                     1314 |             0.154145 |         14 |       372 |     386 |                  92 |
# |           41 | 0 days 00:06:50.225764036 | 0 days 00:00:01.866179228 | 0 days 00:06:48.359584808 | False     |                  14 |      0.110236  |                                     1255 |             0.468504 |         14 |       113 |     127 |                  88 |
# |           42 | 0 days 00:16:05.476376770 | 0 days 00:00:01.672928094 | 0 days 00:16:03.803448676 | False     |                  15 |      0.0482315 |                                     1279 |             0.204984 |         15 |       296 |     311 |                  84 |
# |           43 | 0 days 00:19:54.375036240 | 0 days 00:00:01.534792900 | 0 days 00:19:52.840243340 | False     |                  15 |      0.038961  |                                     1225 |             0.165584 |         15 |       370 |     385 |                  80 |
# |           44 | 0 days 00:07:35.822397941 | 0 days 00:00:01.784064053 | 0 days 00:07:34.038333888 | False     |                  17 |      0.124088  |                                     1316 |             0.527372 |         17 |       120 |     137 |                  76 |
# |           45 | 0 days 00:15:18.468968152 | 0 days 00:00:01.498535872 | 0 days 00:15:16.970432280 | False     |                  18 |      0.0627178 |                                     1322 |             0.266551 |         18 |       269 |     287 |                  72 |
# |           46 | 0 days 00:25:53.741522312 | 0 days 00:00:01.607264996 | 0 days 00:25:52.134257316 | False     |                  18 |      0.036     |                                     1248 |             0.153    |         18 |       482 |     500 |                  68 |
# |           47 | 0 days 00:22:04.698071955 | 0 days 00:00:01.525931835 | 0 days 00:22:03.172140120 | False     |                  20 |      0.0470588 |                                     1314 |             0.2      |         20 |       405 |     425 |                  64 |
# |           48 | 0 days 00:21:44.335694074 | 0 days 00:00:01.481716870 | 0 days 00:21:42.853977204 | False     |                  21 |      0.0503597 |                                     1286 |             0.214029 |         21 |       396 |     417 |                  60 |
# |           49 | 0 days 00:25:08.813821791 | 0 days 00:00:01.723549843 | 0 days 00:25:07.090271948 | False     |                  23 |      0.0474227 |                                     1318 |             0.201546 |         23 |       462 |     485 |                  56 |
# |           50 | 0 days 00:30:23.698394774 | 0 days 00:00:01.718419074 | 0 days 00:30:21.979975700 | False     |                  25 |      0.042735  |                                     1338 |             0.181624 |         25 |       560 |     585 |                  52 |
# |           51 | 0 days 00:41:59.059354067 | 0 days 00:00:01.655703783 | 0 days 00:41:57.403650284 | False     |                  26 |      0.0322581 |                                     1281 |             0.137097 |         26 |       780 |     806 |                  48 |
# |           52 | 0 days 00:27:33.262007714 | 0 days 00:00:01.763319970 | 0 days 00:27:31.498687744 | False     |                  28 |      0.0539499 |                                     1277 |             0.229287 |         28 |       491 |     519 |                  44 |
# |           53 | 0 days 00:36:33.310221672 | 0 days 00:00:01.700650216 | 0 days 00:36:31.609571456 | False     |                  31 |      0.0447977 |                                     1286 |             0.19039  |         31 |       661 |     692 |                  40 |
# |           54 | 0 days 00:41:56.709121226 | 0 days 00:00:01.637687206 | 0 days 00:41:55.071434020 | False     |                  34 |      0.042394  |                                     1274 |             0.180175 |         34 |       768 |     802 |                  36 |
# |           55 | 0 days 00:52:05.019674540 | 0 days 00:00:01.651765108 | 0 days 00:52:03.367909432 | False     |                  39 |      0.039     |                                     1307 |             0.16575  |         39 |       961 |    1000 |                  32 |
# |           56 | 0 days 00:39:30.516080140 | 0 days 00:00:01.923462152 | 0 days 00:39:28.592617988 | False     |                  45 |      0.0613079 |                                     1341 |             0.260559 |         45 |       689 |     734 |                  28 |
# |           57 | 0 days 00:54:41.795562505 | 0 days 00:00:01.671502829 | 0 days 00:54:40.124059676 | False     |                  51 |      0.049323  |                                     1301 |             0.209623 |         51 |       983 |    1034 |                  24 |
# |           58 | 0 days 00:56:06.227320905 | 0 days 00:00:01.717213869 | 0 days 00:56:04.510107036 | False     |                  61 |      0.0584851 |                                     1315 |             0.248562 |         61 |       982 |    1043 |                  20 |
# |           59 | 0 days 01:29:12.972656726 | 0 days 00:00:01.795652866 | 0 days 01:29:11.177003860 | False     |                  75 |      0.044405  |                                     1312 |             0.188721 |         75 |      1614 |    1689 |                  16 |
# |           60 | 0 days 01:46:15.552562712 | 0 days 00:00:02.023939132 | 0 days 01:46:13.528623580 | False     |                 102 |      0.0503704 |                                     1375 |             0.214074 |        102 |      1923 |    2025 |                  12 |
# |           61 | 0 days 02:02:09.718218088 | 0 days 00:00:02.329063652 | 0 days 02:02:07.389154436 | False     |                 132 |      0.0568475 |                                     1286 |             0.241602 |        132 |      2190 |    2322 |                   8 |
# |           62 | 0 days 03:14:37.013703587 | 0 days 00:00:02.577142955 | 0 days 03:14:34.436560632 | False     |                 225 |      0.0609591 |                                     1269 |             0.259076 |        225 |      3466 |    3691 |                   4 |

# %%
df_latex = df_print[[
    'min_zeroed_coeffs',
    'num_distinct_sigs',
    'num_good',
    'num_bad',
    'total',
    'time_total'
]]
# time format
df_latex.loc[:,'time_total'] = df_latex['time_total'].apply(lambda x: f'{x.components.hours}:{x.components.minutes:02d}')

df_latex = df_latex.tail(5)
df_latex = df_latex.iloc[::-1]
df_latex = df_latex.rename(columns={
    'min_zeroed_coeffs': '# Skipped coefficients',
    'num_distinct_sigs': '# Signatures ',
    'num_bad': '# Failures ',
    'num_good': '# Successes',
    'total': '# Required queries',
    'time_total': 'Execution time (hh:mm)'
})

display(df_latex)
print(df_latex.rename(columns=lambda x: x.replace('#', '\\#')).to_latex(index=False, column_format='r' * len(df_latex.columns)))
# Out:
#             # Skipped coefficients  # Signatures   # Successes  # Failures
# poly_index
# 62                               4            225          225         3466  \
# 61                               8            132          132         2190
# 60                              12            102          102         1923
# 59                              16             75           75         1614
# 58                              20             61           61          982
#
#             # Required queries Execution time (hh:mm)
# poly_index
# 62                        3691                   3:14
# 61                        2322                   2:02
# 60                        2025                   1:46
# 59                        1689                   1:29
# 58                        1043                   0:56
# \begin{tabular}{rrrrrr}
# \toprule
# \# Skipped coefficients & \# Signatures  & \# Successes & \# Failures  & \# Required queries & Execution time (hh:mm) \\
# \midrule
# 4 & 225 & 225 & 3466 & 3691 & 3:14 \\
# 8 & 132 & 132 & 2190 & 2322 & 2:02 \\
# 12 & 102 & 102 & 1923 & 2025 & 1:46 \\
# 16 & 75 & 75 & 1614 & 1689 & 1:29 \\
# 20 & 61 & 61 & 982 & 1043 & 0:56 \\
# \bottomrule
# \end{tabular}
